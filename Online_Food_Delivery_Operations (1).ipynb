# %% [markdown]
# #A food delivery company wants to improve delivery time, reduce cancellations, and understand which areas and restaurants are operationally weak.

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder\
    .appName("Food delivery")\
    .getOrCreate()

# %% [markdown]
# #PHASE 1 – Ingestion

# %% [markdown]
# ## Read delivery_data.csv as all StringType

# %%
from pyspark.sql.types import StructType, StructField, StringType

schema = StructType([
    StructField("order_id", StringType(), True),
    StructField("customer_id", StringType(), True),
    StructField("restaurant_id", StringType(), True),
    StructField("restaurant_city", StringType(), True),
    StructField("delivery_city", StringType(), True),
    StructField("order_time", StringType(), True),
    StructField("pickup_time", StringType(), True),
    StructField("delivery_time", StringType(), True),
    StructField("delivery_status", StringType(), True),
    StructField("delivery_partner_id", StringType(), True),
    StructField("order_amount", StringType(), True),
    StructField("payment_mode", StringType(), True),
    StructField("rating", StringType(), True)
])

# %%
df = spark.read.csv(
    "delivery_data.csv",
    header=True,
    schema=schema
)

# %% [markdown]
# #Print schema

# %%
df.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- restaurant_id: string (nullable = true)
#  |-- restaurant_city: string (nullable = true)
#  |-- delivery_city: string (nullable = true)
#  |-- order_time: string (nullable = true)
#  |-- pickup_time: string (nullable = true)
#  |-- delivery_time: string (nullable = true)
#  |-- delivery_status: string (nullable = true)
#  |-- delivery_partner_id: string (nullable = true)
#  |-- order_amount: string (nullable = true)
#  |-- payment_mode: string (nullable = true)
#  |-- rating: string (nullable = true)

# %% [markdown]
# #  Print record count

# %%
df.count()
# Out:
# 150000

# %% [markdown]
# # Show sample rows

# %%
df.show(10, truncate=False)
# Out:
# +--------+-----------+-------------+---------------+-------------+-------------------+-------------------+-------------------+---------------+-------------------+------------+------------+------+
# |order_id|customer_id|restaurant_id|restaurant_city|delivery_city|order_time         |pickup_time        |delivery_time      |delivery_status|delivery_partner_id|order_amount|payment_mode|rating|
# +--------+-----------+-------------+---------------+-------------+-------------------+-------------------+-------------------+---------------+-------------------+------------+------------+------+
# |O100000 |C9467      |R972         |Bangalore      |Chennai      |29/01/2026 04:16:00|NULL               |NULL               |CANCELLED      |D505               |invalid     |COD         |NULL  |
# |O100001 |C1081      |R675         |Pune           |Bangalore    |2026-01-29 17:48:00|2026-01-29 18:16:00|2026-01-29 18:16:00|PLACED         |D359               |304         |CreditCard  |NULL  |
# |O100002 |C3136      |R713         |Bangalore      |Bangalore    |2026-01-31 16:26:00|2026-01-31 16:50:00|2026-01-31 17:27:00|CANCELLED      |D702               |757         |CreditCard  |NULL  |
# |O100003 |C3022      |R614         |Pune           |Bangalore    |2026-01-06 03:03:00|2026-01-06 03:23:00|2026-01-06 04:21:00|PLACED         |D707               |729         |DebitCard   |NULL  |
# |O100004 |C3883      |R655         |Hyderabad      |Chennai      |2026-01-13 10:20:00|2026-01-13 10:20:00|2026-01-13 11:19:00|DELIVERED      |D129               |2318        |Wallet      |1.7   |
# |O100005 |C6981      |R842         |Pune           |Mumbai       |2026-01-28 04:25:00|2026-01-28 04:45:00|2026-01-28 05:15:00|PICKED         |D311               |1696        |Wallet      |NULL  |
# |O100006 |C4090      |R919         |Kolkata        |Bangalore    |2026-01-22 19:29:00|2026-01-22 19:30:00|2026-01-22 19:45:00|PLACED         |D796               |675         |DebitCard   |NULL  |
# |O100007 |C1644      |R944         |Bangalore      |Kolkata      |2026-01-13 16:38:00|2026-01-13 16:52:00|2026-01-13 17:08:00|CANCELLED      |D543               |2400        |CreditCard  |NULL  |
# |O100008 |C8957      |R876         |Bangalore      |Hyderabad    |2026-01-14 00:02:00|2026-01-14 00:01:00|2026-01-14 00:58:00|PICKED         |D687               |815         |DebitCard   |NULL  |
# |O100009 |C2976      |R226         |Bangalore      |Hyderabad    |2026-01-12 03:53:00|2026-01-12 04:21:00|2026-01-12 04:55:00|DELIVERED      |D601               |1054        |Wallet      |1.5   |
# +--------+-----------+-------------+---------------+-------------+-------------------+-------------------+-------------------+---------------+-------------------+------------+------------+------+
# only showing top 10 rows

# %% [markdown]
#  # Identify obvious data issues

# %%
df.filter(df.pickup_time.isNull()).count()
# Out:
# 13637

# %%
df.filter(df.delivery_time.isNull()).count()
# Out:
# 11539

# %%
df.filter((df.delivery_status == "DELIVERED") & (df.delivery_time.isNull())).show(10, truncate=False)
# Out:
# +--------+-----------+-------------+---------------+-------------+-------------------+-------------------+-------------+---------------+-------------------+------------+------------+------+
# |order_id|customer_id|restaurant_id|restaurant_city|delivery_city|order_time         |pickup_time        |delivery_time|delivery_status|delivery_partner_id|order_amount|payment_mode|rating|
# +--------+-----------+-------------+---------------+-------------+-------------------+-------------------+-------------+---------------+-------------------+------------+------------+------+
# |O100078 |C7435      |R541         |Kolkata        |Hyderabad    |2026-01-04 04:37:00|2026-01-04 04:47:00|NULL         |DELIVERED      |D180               |543         |DebitCard   |3.0   |
# |O100104 |C9179      |R131         |Kolkata        |Bangalore    |2026-01-30 15:50:00|2026-01-30 16:18:00|NULL         |DELIVERED      |D598               |771         |COD         |2.8   |
# |O100117 |C8727      |R688         |Chennai        |Mumbai       |2026-01-04 07:51:00|2026-01-04 08:10:00|NULL         |DELIVERED      |D277               |1951        |UPI         |2.0   |
# |O100130 |C6009      |R741         |Delhi          |Kolkata      |2026-01-07 13:00:00|2026-01-07 13:19:00|NULL         |DELIVERED      |D235               |759         |CreditCard  |3.6   |
# |O100260 |C9239      |R724         |Delhi          |Hyderabad    |2026-01-25 11:54:00|2026-01-25 12:02:00|NULL         |DELIVERED      |D498               |1862        |DebitCard   |3.7   |
# |O100338 |C9397      |R212         |Delhi          |Delhi        |2026-01-07 10:54:00|2026-01-07 11:01:00|NULL         |DELIVERED      |D764               |277         |CreditCard  |4.7   |
# |O100364 |C5734      |R221         |Chennai        |Mumbai       |2026-01-16 09:33:00|2026-01-16 09:49:00|NULL         |DELIVERED      |D450               |724         |UPI         |2.6   |
# |O100390 |C8140      |R379         |Mumbai         |Chennai      |2026-01-23 02:17:00|2026-01-23 02:46:00|NULL         |DELIVERED      |D148               |537         |Wallet      |2.3   |
# |O100403 |C1190      |R302         |Chennai        |Chennai      |2026-01-06 03:41:00|2026-01-06 03:49:00|NULL         |DELIVERED      |D369               |5,409       |CreditCard  |4.7   |
# |O100416 |C3801      |R371         |Pune           |Kolkata      |2026-01-28 08:30:00|2026-01-28 08:52:00|NULL         |DELIVERED      |D795               |1846        |CreditCard  |2.1   |
# +--------+-----------+-------------+---------------+-------------+-------------------+-------------------+-------------+---------------+-------------------+------------+------------+------+
# only showing top 10 rows

# %%
df.filter((df.delivery_status == "DELIVERED") & (df.delivery_time.isNull())).count()
# Out:
# 2817

# %% [markdown]
# # PHASE 2 – Cleaning

# %%
from pyspark.sql.functions import (
    col, trim, when, regexp_replace, coalesce, to_timestamp, lit
)
from pyspark.sql.types import IntegerType

# %% [markdown]
# #  Trim all string columns

# %%
time_cols = ["order_time", "pickup_time", "delivery_time"]

# %%
string_cols = [name for (name, dtype) in df.dtypes if dtype == "string" and name not in time_cols]

# %%
for c in string_cols:
    df = df.withColumn(
        c,
        when(col(c).isNull() | (trim(col(c)) == ""), None).otherwise(trim(col(c)))
    )

# %% [markdown]
# #  Clean order_amount

# %% [markdown]
# ## Remove commas

# %%
df = df.withColumn("order_amount_nocommas", regexp_replace(col("order_amount"), ",", ""))

# %% [markdown]
# ## Convert to IntegerType

# %%
df = df.withColumn(
    "order_amount_clean",
    when(col("order_amount_nocommas").rlike(r"^\d+$"), col("order_amount_nocommas").cast(IntegerType()))
    .otherwise(lit(None).cast(IntegerType()))
)

# %% [markdown]
# ## Handle invalid values safely

# %%
df = df.withColumn(
    "order_amount_clean",
    when(col("order_amount_clean") < 0, None).otherwise(col("order_amount_clean"))
)

# %%
df = df.withColumn("order_amount_valid", col("order_amount_clean").isNotNull())

# %%
df = df.drop("order_amount_nocommas")

# %%
df.count()
# Out:
# 150000

# %% [markdown]
# # Parse timestamps into:
# *   order_time_clean
# *   pickup_time_clean
# *   delivery_time_clean

# %%
from pyspark.sql.functions import (
    try_to_timestamp, upper
)

# %%
df.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- restaurant_id: string (nullable = true)
#  |-- restaurant_city: string (nullable = true)
#  |-- delivery_city: string (nullable = true)
#  |-- order_time: string (nullable = true)
#  |-- pickup_time: string (nullable = true)
#  |-- delivery_time: string (nullable = true)
#  |-- delivery_status: string (nullable = true)
#  |-- delivery_partner_id: string (nullable = true)
#  |-- order_amount: string (nullable = true)
#  |-- payment_mode: string (nullable = true)
#  |-- rating: string (nullable = true)
#  |-- order_amount_clean: integer (nullable = true)
#  |-- order_amount_valid: boolean (nullable = false)

# %% [markdown]
# # Support multiple formats:
# *   yyyy-MM-dd HH:mm:ss
# *   dd/MM/yyyy HH:mm:ss
# *   yyyy/MM/dd HH:mm:ss

# %% [markdown]
# # Keep original columns for audit

# %%
from pyspark.sql.functions import col, expr

formats = [
    "yyyy-MM-dd HH:mm:ss",
    "dd/MM/yyyy HH:mm:ss",
    "yyyy/MM/dd HH:mm:ss"
]

# %%
def parse_multi_format_ts_expr(colname):
    norm = f"""
      CASE
        WHEN {colname} IS NULL THEN NULL
        WHEN TRIM({colname}) = '' THEN NULL
        WHEN UPPER(TRIM({colname})) = 'NULL' THEN NULL
        ELSE TRIM({colname})
      END
    """
    tries = ", ".join([f"try_to_timestamp({norm}, '{fmt}')" for fmt in formats])
    return expr(f"coalesce({tries})")

# %%
df = df.withColumn("order_time_clean",    parse_multi_format_ts_expr("order_time")) \
       .withColumn("pickup_time_clean",   parse_multi_format_ts_expr("pickup_time")) \
       .withColumn("delivery_time_clean", parse_multi_format_ts_expr("delivery_time"))

# %% [markdown]
# # Create flags:
# *   order_time_valid
# *   pickup_time_valid
# *   delivery_time_valid

# %%
df = df.withColumn("order_time_valid",     col("order_time_clean").isNotNull()) \
       .withColumn("pickup_time_valid",    col("pickup_time_clean").isNotNull()) \
       .withColumn("delivery_time_valid",  col("delivery_time_clean").isNotNull())

# %%
df.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- restaurant_id: string (nullable = true)
#  |-- restaurant_city: string (nullable = true)
#  |-- delivery_city: string (nullable = true)
#  |-- order_time: string (nullable = true)
#  |-- pickup_time: string (nullable = true)
#  |-- delivery_time: string (nullable = true)
#  |-- delivery_status: string (nullable = true)
#  |-- delivery_partner_id: string (nullable = true)
#  |-- order_amount: string (nullable = true)
#  |-- payment_mode: string (nullable = true)
#  |-- rating: string (nullable = true)
#  |-- order_amount_clean: integer (nullable = true)
#  |-- order_amount_valid: boolean (nullable = false)
#  |-- order_time_clean: timestamp (nullable = true)
#  |-- pickup_time_clean: timestamp (nullable = true)
#  |-- delivery_time_clean: timestamp (nullable = true)
#  |-- order_time_valid: boolean (nullable = false)
#  |-- pickup_time_valid: boolean (nullable = false)
#  |-- delivery_time_valid: boolean (nullable = false)

# %%
df.select(
    "order_id",
    "order_time", "order_time_clean", "order_time_valid",
    "pickup_time", "pickup_time_clean", "pickup_time_valid",
    "delivery_time", "delivery_time_clean", "delivery_time_valid"
).show(20, truncate=False)

print("Order time invalid:", df.filter(~col("order_time_valid")).count())
print("Pickup time invalid:", df.filter(~col("pickup_time_valid")).count())
print("Delivery time invalid:", df.filter(~col("delivery_time_valid")).count())
# Out:
# +--------+-------------------+-------------------+----------------+-------------------+-------------------+-----------------+-------------------+-------------------+-------------------+
# |order_id|order_time         |order_time_clean   |order_time_valid|pickup_time        |pickup_time_clean  |pickup_time_valid|delivery_time      |delivery_time_clean|delivery_time_valid|
# +--------+-------------------+-------------------+----------------+-------------------+-------------------+-----------------+-------------------+-------------------+-------------------+
# |O100000 |29/01/2026 04:16:00|2026-01-29 04:16:00|true            |NULL               |NULL               |false            |NULL               |NULL               |false              |
# |O100001 |2026-01-29 17:48:00|2026-01-29 17:48:00|true            |2026-01-29 18:16:00|2026-01-29 18:16:00|true             |2026-01-29 18:16:00|2026-01-29 18:16:00|true               |
# |O100002 |2026-01-31 16:26:00|2026-01-31 16:26:00|true            |2026-01-31 16:50:00|2026-01-31 16:50:00|true             |2026-01-31 17:27:00|2026-01-31 17:27:00|true               |
# |O100003 |2026-01-06 03:03:00|2026-01-06 03:03:00|true            |2026-01-06 03:23:00|2026-01-06 03:23:00|true             |2026-01-06 04:21:00|2026-01-06 04:21:00|true               |
# |O100004 |2026-01-13 10:20:00|2026-01-13 10:20:00|true            |2026-01-13 10:20:00|2026-01-13 10:20:00|true             |2026-01-13 11:19:00|2026-01-13 11:19:00|true               |
# |O100005 |2026-01-28 04:25:00|2026-01-28 04:25:00|true            |2026-01-28 04:45:00|2026-01-28 04:45:00|true             |2026-01-28 05:15:00|2026-01-28 05:15:00|true               |
# |O100006 |2026-01-22 19:29:00|2026-01-22 19:29:00|true            |2026-01-22 19:30:00|2026-01-22 19:30:00|true             |2026-01-22 19:45:00|2026-01-22 19:45:00|true               |
# |O100007 |2026-01-13 16:38:00|2026-01-13 16:38:00|true            |2026-01-13 16:52:00|2026-01-13 16:52:00|true             |2026-01-13 17:08:00|2026-01-13 17:08:00|true               |
# |O100008 |2026-01-14 00:02:00|2026-01-14 00:02:00|true            |2026-01-14 00:01:00|2026-01-14 00:01:00|true             |2026-01-14 00:58:00|2026-01-14 00:58:00|true               |
# |O100009 |2026-01-12 03:53:00|2026-01-12 03:53:00|true            |2026-01-12 04:21:00|2026-01-12 04:21:00|true             |2026-01-12 04:55:00|2026-01-12 04:55:00|true               |
# |O100010 |2026-01-15 14:13:00|2026-01-15 14:13:00|true            |2026-01-15 14:10:00|2026-01-15 14:10:00|true             |2026-01-15 14:43:00|2026-01-15 14:43:00|true               |
# |O100011 |2026-01-04 02:10:00|2026-01-04 02:10:00|true            |NULL               |NULL               |false            |2026-01-04 03:06:00|2026-01-04 03:06:00|true               |
# |O100012 |2026-01-23 19:44:00|2026-01-23 19:44:00|true            |2026-01-23 19:59:00|2026-01-23 19:59:00|true             |2026-01-23 20:33:00|2026-01-23 20:33:00|true               |
# |O100013 |2026-01-01 12:40:00|2026-01-01 12:40:00|true            |2026-01-01 13:05:00|2026-01-01 13:05:00|true             |NULL               |NULL               |false              |
# |O100014 |2026-01-11 10:10:00|2026-01-11 10:10:00|true            |2026-01-11 10:17:00|2026-01-11 10:17:00|true             |2026-01-11 10:50:00|2026-01-11 10:50:00|true               |
# |O100015 |2026-01-20 15:13:00|2026-01-20 15:13:00|true            |2026-01-20 15:15:00|2026-01-20 15:15:00|true             |2026-01-20 15:49:00|2026-01-20 15:49:00|true               |
# |O100016 |2026-01-16 22:05:00|2026-01-16 22:05:00|true            |2026-01-16 22:09:00|2026-01-16 22:09:00|true             |2026-01-16 23:02:00|2026-01-16 23:02:00|true               |
# |O100017 |03/01/2026 18:06:00|2026-01-03 18:06:00|true            |2026-01-03 18:27:00|2026-01-03 18:27:00|true             |2026-01-03 18:40:00|2026-01-03 18:40:00|true               |
# |O100018 |2026-02-04 17:50:00|2026-02-04 17:50:00|true            |2026-02-04 18:08:00|2026-02-04 18:08:00|true             |2026-02-04 18:56:00|2026-02-04 18:56:00|true               |
# |O100019 |2026-01-25 22:39:00|2026-01-25 22:39:00|true            |2026-01-25 23:06:00|2026-01-25 23:06:00|true             |2026-01-25 23:17:00|2026-01-25 23:17:00|true               |
# +--------+-------------------+-------------------+----------------+-------------------+-------------------+-----------------+-------------------+-------------------+-------------------+
# only showing top 20 rows
# Order time invalid: 0
# Pickup time invalid: 13637
# Delivery time invalid: 11539

# %% [markdown]
# # PHASE 3 – Derived Metrics

# %%
from pyspark.sql.functions import col, when, lit, round as spark_round

def minutes_diff(end_col, start_col):
    return (col(end_col).cast("long") - col(start_col).cast("long")) / lit(60.0)

# %% [markdown]
# # Create time-based metrics:
# *   prep_time    = pickup_time - order_time
# *   delivery_time_gap = delivery_time - pickup_time
# *   total_fulfillment_time = delivery_time - order_time

# %%
df = df.withColumn(
    "prep_time_min",
    when(col("pickup_time_clean").isNotNull() & col("order_time_clean").isNotNull(),
         minutes_diff("pickup_time_clean", "order_time_clean")
    ).otherwise(lit(None).cast("double"))
)

# %%
df = df.withColumn(
    "delivery_time_gap_min",
    when(col("delivery_time_clean").isNotNull() & col("pickup_time_clean").isNotNull(),
         minutes_diff("delivery_time_clean", "pickup_time_clean")
    ).otherwise(lit(None).cast("double"))
)

# %%
df.select(
    "order_id",
    "order_time_clean", "pickup_time_clean", "delivery_time_clean",
    "prep_time_min", "delivery_time_gap_min", "total_fulfillment_time_min",
    "prep_time_negative", "delivery_time_gap_negative", "total_fulfillment_time_negative"
).show(20, truncate=False)
# Out:
# +--------+-------------------+-------------------+-------------------+-------------+---------------------+--------------------------+------------------+--------------------------+-------------------------------+
# |order_id|order_time_clean   |pickup_time_clean  |delivery_time_clean|prep_time_min|delivery_time_gap_min|total_fulfillment_time_min|prep_time_negative|delivery_time_gap_negative|total_fulfillment_time_negative|
# +--------+-------------------+-------------------+-------------------+-------------+---------------------+--------------------------+------------------+--------------------------+-------------------------------+
# |O100000 |2026-01-29 04:16:00|NULL               |NULL               |NULL         |NULL                 |NULL                      |false             |false                     |false                          |
# |O100001 |2026-01-29 17:48:00|2026-01-29 18:16:00|2026-01-29 18:16:00|28.0         |0.0                  |28.0                      |false             |false                     |false                          |
# |O100002 |2026-01-31 16:26:00|2026-01-31 16:50:00|2026-01-31 17:27:00|24.0         |37.0                 |61.0                      |false             |false                     |false                          |
# |O100003 |2026-01-06 03:03:00|2026-01-06 03:23:00|2026-01-06 04:21:00|20.0         |58.0                 |78.0                      |false             |false                     |false                          |
# |O100004 |2026-01-13 10:20:00|2026-01-13 10:20:00|2026-01-13 11:19:00|0.0          |59.0                 |59.0                      |false             |false                     |false                          |
# |O100005 |2026-01-28 04:25:00|2026-01-28 04:45:00|2026-01-28 05:15:00|20.0         |30.0                 |50.0                      |false             |false                     |false                          |
# |O100006 |2026-01-22 19:29:00|2026-01-22 19:30:00|2026-01-22 19:45:00|1.0          |15.0                 |16.0                      |false             |false                     |false                          |
# |O100007 |2026-01-13 16:38:00|2026-01-13 16:52:00|2026-01-13 17:08:00|14.0         |16.0                 |30.0                      |false             |false                     |false                          |
# |O100008 |2026-01-14 00:02:00|2026-01-14 00:01:00|2026-01-14 00:58:00|-1.0         |57.0                 |56.0                      |true              |false                     |false                          |
# |O100009 |2026-01-12 03:53:00|2026-01-12 04:21:00|2026-01-12 04:55:00|28.0         |34.0                 |62.0                      |false             |false                     |false                          |
# |O100010 |2026-01-15 14:13:00|2026-01-15 14:10:00|2026-01-15 14:43:00|-3.0         |33.0                 |30.0                      |true              |false                     |false                          |
# |O100011 |2026-01-04 02:10:00|NULL               |2026-01-04 03:06:00|NULL         |NULL                 |56.0                      |false             |false                     |false                          |
# |O100012 |2026-01-23 19:44:00|2026-01-23 19:59:00|2026-01-23 20:33:00|15.0         |34.0                 |49.0                      |false             |false                     |false                          |
# |O100013 |2026-01-01 12:40:00|2026-01-01 13:05:00|NULL               |25.0         |NULL                 |NULL                      |false             |false                     |false                          |
# |O100014 |2026-01-11 10:10:00|2026-01-11 10:17:00|2026-01-11 10:50:00|7.0          |33.0                 |40.0                      |false             |false                     |false                          |
# |O100015 |2026-01-20 15:13:00|2026-01-20 15:15:00|2026-01-20 15:49:00|2.0          |34.0                 |36.0                      |false             |false                     |false                          |
# |O100016 |2026-01-16 22:05:00|2026-01-16 22:09:00|2026-01-16 23:02:00|4.0          |53.0                 |57.0                      |false             |false                     |false                          |
# |O100017 |2026-01-03 18:06:00|2026-01-03 18:27:00|2026-01-03 18:40:00|21.0         |13.0                 |34.0                      |false             |false                     |false                          |
# |O100018 |2026-02-04 17:50:00|2026-02-04 18:08:00|2026-02-04 18:56:00|18.0         |48.0                 |66.0                      |false             |false                     |false                          |
# |O100019 |2026-01-25 22:39:00|2026-01-25 23:06:00|2026-01-25 23:17:00|27.0         |11.0                 |38.0                      |false             |false                     |false                          |
# +--------+-------------------+-------------------+-------------------+-------------+---------------------+--------------------------+------------------+--------------------------+-------------------------------+
# only showing top 20 rows

# %% [markdown]
# # PHASE 4 – Data Validation

# %% [markdown]
# # Count rows where:
# *   pickup_time < order_time
# *   delivery_time < pickup_time

# %%
pickup_before_order = df.filter(
    col("pickup_time_clean").isNotNull() &
    col("order_time_clean").isNotNull() &
    (col("pickup_time_clean") < col("order_time_clean"))
).count()

# %%
delivery_before_pickup = df.filter(
    col("delivery_time_clean").isNotNull() &
    col("pickup_time_clean").isNotNull() &
    (col("delivery_time_clean") < col("pickup_time_clean"))
).count()

# %% [markdown]
# # Count rows where delivery_status = DELIVERED but delivery_time is null

# %%
delivered_without_delivery_time = df.filter(
    (col("delivery_status") == "DELIVERED") &
    (col("delivery_time_clean").isNull())
).count()

# %%
delivered_without_delivery_time
# Out:
# 2817

# %% [markdown]
# #  Count rows with invalid amounts

# %%
invalid_amount_rows = df.filter(~col("order_amount_valid")).count()

# %%
invalid_amount_rows
# Out:
# 14073

# %% [markdown]
# #  Count CANCELLED orders

# %%
cancelled_orders = df.filter(col("delivery_status") == "CANCELLED").count()

# %%
cancelled_orders
# Out:
# 37658

# %% [markdown]
# # OPERATIONAL DATA QUALITY REPORT

# %%
quality_report = {
    "pickup_before_order_time_rows": pickup_before_order,
    "delivery_before_pickup_time_rows": delivery_before_pickup,
    "delivered_but_no_delivery_time_rows": delivered_without_delivery_time,
    "invalid_order_amount_rows": invalid_amount_rows,
    "cancelled_orders_rows": cancelled_orders
}

print("\n=== OPERATIONAL DATA QUALITY REPORT ===")
for k, v in quality_report.items():
    print(f"{k}: {v}")
# Out:
# === OPERATIONAL DATA QUALITY REPORT ===
# pickup_before_order_time_rows: 19095
# delivery_before_pickup_time_rows: 17650
# delivered_but_no_delivery_time_rows: 2817
# invalid_order_amount_rows: 14073
# cancelled_orders_rows: 37658

# %% [markdown]
# # PHASE 5 – Operational Analytics

# %% [markdown]
# # Average prep_time per restaurant

# %%
from pyspark.sql.functions import col, avg, count, sum as spark_sum, round as spark_round

prep_valid_filter = col("prep_time_min").isNotNull() & ~col("prep_time_negative")
gap_valid_filter = col("delivery_time_gap_min").isNotNull() & ~col("delivery_time_gap_negative")
total_valid_filter = col("total_fulfillment_time_min").isNotNull() & ~col("total_fulfillment_time_negative")

# %%
avg_prep_per_restaurant = (
    df.filter(prep_valid_filter)
      .groupBy("restaurant_id", "restaurant_city")
      .agg(
          spark_round(avg(col("prep_time_min")), 2).alias("avg_prep_time_min"),
          count(lit(1)).alias("orders_count")
      )
      .orderBy(col("avg_prep_time_min").desc())
)

avg_prep_per_restaurant.show(20, truncate=False)
# Out:
# +-------------+---------------+-----------------+------------+
# |restaurant_id|restaurant_city|avg_prep_time_min|orders_count|
# +-------------+---------------+-----------------+------------+
# |R597         |Kolkata        |24.09            |11          |
# |R531         |Pune           |24.0             |8           |
# |R568         |Delhi          |23.12            |17          |
# |R280         |Delhi          |22.87            |15          |
# |R618         |Kolkata        |22.47            |15          |
# |R622         |Mumbai         |22.35            |17          |
# |R924         |Chennai        |22.27            |22          |
# |R583         |Pune           |22.0             |16          |
# |R725         |Kolkata        |22.0             |14          |
# |R539         |Delhi          |21.72            |18          |
# |R885         |Pune           |21.64            |14          |
# |R822         |Hyderabad      |21.5             |10          |
# |R841         |Chennai        |21.36            |14          |
# |R338         |Pune           |21.31            |16          |
# |R754         |Kolkata        |21.27            |15          |
# |R521         |Mumbai         |21.24            |17          |
# |R539         |Pune           |21.19            |16          |
# |R975         |Mumbai         |21.13            |16          |
# |R610         |Hyderabad      |21.13            |15          |
# |R839         |Chennai        |21.0             |13          |
# +-------------+---------------+-----------------+------------+
# only showing top 20 rows

# %% [markdown]
# #  Average delivery_time_gap per delivery city

# %%
avg_gap_per_city = (
    df.filter(gap_valid_filter)
      .groupBy("delivery_city")
      .agg(
          spark_round(avg(col("delivery_time_gap_min")), 2).alias("avg_delivery_time_gap_min"),
          count(lit(1)).alias("orders_count")
      )
      .orderBy(col("avg_delivery_time_gap_min").desc())
)

avg_gap_per_city.show(20, truncate=False)
# Out:
# +-------------+-------------------------+------------+
# |delivery_city|avg_delivery_time_gap_min|orders_count|
# +-------------+-------------------------+------------+
# |Mumbai       |30.16                    |15259       |
# |Delhi        |30.12                    |15527       |
# |Kolkata      |30.11                    |15437       |
# |Pune         |30.1                     |15358       |
# |Bangalore    |30.02                    |15628       |
# |Chennai      |30.02                    |15748       |
# |Hyderabad    |29.91                    |15266       |
# +-------------+-------------------------+------------+

# %% [markdown]
# # Top 10 slowest restaurants

# %%
slowest_restaurants_top10 = (
    df.filter(total_valid_filter)
      .groupBy("restaurant_id", "restaurant_city")
      .agg(
          spark_round(avg(col("total_fulfillment_time_min")), 2).alias("avg_total_fulfillment_time_min"),
          count(lit(1)).alias("orders_count")
      )
      .orderBy(col("avg_total_fulfillment_time_min").desc())
      .limit(10)
)

slowest_restaurants_top10.show(10, truncate=False)
# Out:
# +-------------+---------------+------------------------------+------------+
# |restaurant_id|restaurant_city|avg_total_fulfillment_time_min|orders_count|
# +-------------+---------------+------------------------------+------------+
# |R614         |Chennai        |57.23                         |13          |
# |R871         |Hyderabad      |56.47                         |17          |
# |R769         |Delhi          |55.88                         |16          |
# |R792         |Chennai        |55.82                         |17          |
# |R977         |Bangalore      |55.8                          |20          |
# |R904         |Mumbai         |55.0                          |18          |
# |R638         |Hyderabad      |54.71                         |17          |
# |R684         |Bangalore      |54.69                         |16          |
# |R839         |Kolkata        |54.63                         |16          |
# |R252         |Kolkata        |54.56                         |16          |
# +-------------+---------------+------------------------------+------------+

# %% [markdown]
# # Cities with highest average delivery time

# %%
cities_highest_avg_total = (
    df.filter(total_valid_filter)
      .groupBy("delivery_city")
      .agg(
          spark_round(avg(col("total_fulfillment_time_min")), 2).alias("avg_total_fulfillment_time_min"),
          count(lit(1)).alias("orders_count")
      )
      .orderBy(col("avg_total_fulfillment_time_min").desc())
)

cities_highest_avg_total.show(20, truncate=False)
# Out:
# +-------------+------------------------------+------------+
# |delivery_city|avg_total_fulfillment_time_min|orders_count|
# +-------------+------------------------------+------------+
# |Mumbai       |39.82                         |18653       |
# |Kolkata      |39.71                         |18814       |
# |Bangalore    |39.7                          |18997       |
# |Pune         |39.68                         |18822       |
# |Delhi        |39.66                         |18873       |
# |Hyderabad    |39.65                         |18592       |
# |Chennai      |39.56                         |19204       |
# +-------------+------------------------------+------------+

# %% [markdown]
# #  Cancellation percentage per city

# %%
from pyspark.sql.functions import when, lit

city_cancel_stats = (
    df.groupBy("delivery_city")
      .agg(
          count(lit(1)).alias("total_orders"),
          spark_sum(when(col("delivery_status") == "CANCELLED", 1).otherwise(0)).alias("cancelled_orders")
      )
      .withColumn(
          "cancellation_pct",
          spark_round((col("cancelled_orders") / col("total_orders")) * 100.0, 2)
      )
      .orderBy(col("cancellation_pct").desc(), col("total_orders").desc())
)

city_cancel_stats.show(50, truncate=False)
# Out:
# +-------------+------------+----------------+----------------+
# |delivery_city|total_orders|cancelled_orders|cancellation_pct|
# +-------------+------------+----------------+----------------+
# |Kolkata      |21401       |5488            |25.64           |
# |Chennai      |21742       |5499            |25.29           |
# |Mumbai       |21192       |5354            |25.26           |
# |Hyderabad    |21173       |5343            |25.23           |
# |Delhi        |21538       |5390            |25.03           |
# |Pune         |21409       |5319            |24.84           |
# |Bangalore    |21545       |5265            |24.44           |
# +-------------+------------+----------------+----------------+

# %% [markdown]
# # PHASE 6 – Window Functions

# %% [markdown]
# # Rank restaurants by:
# *   Average fulfillment time
# *   Cancellation rate

# %%
from pyspark.sql import Window
from pyspark.sql.functions import (
   lit, dense_rank
)

# %%
restaurant_time_agg = (
    df.filter(total_valid_filter)
      .groupBy("restaurant_id", "restaurant_city")
      .agg(
          spark_round(avg(col("total_fulfillment_time_min")), 2).alias("avg_total_fulfillment_time_min"),
          count(lit(1)).alias("orders_with_valid_time")
      )
)

# %%
restaurant_cancel_agg = (
    df.groupBy("restaurant_id", "restaurant_city")
      .agg(
          count(lit(1)).alias("total_orders"),
          spark_sum(when(col("delivery_status") == "CANCELLED", 1).otherwise(0)).alias("cancelled_orders")
      )
      .withColumn(
          "cancellation_rate_pct",
          when(col("total_orders") > 0, (col("cancelled_orders") / col("total_orders")) * 100.0).otherwise(lit(None).cast("double"))
      )
      .withColumn("cancellation_rate_pct", spark_round(col("cancellation_rate_pct"), 2))
)

# %%
restaurants_ranked = (
    restaurant_time_agg.join(restaurant_cancel_agg, on=["restaurant_id", "restaurant_city"], how="outer")
)

# %%
w_avg_fulfillment = Window.orderBy(col("avg_total_fulfillment_time_min").asc())
w_cancel_rate     = Window.orderBy(col("cancellation_rate_pct").asc())

restaurants_ranked = (
    restaurants_ranked
      .withColumn("rank_by_avg_fulfillment", dense_rank().over(w_avg_fulfillment))
      .withColumn("rank_by_cancellation_rate", dense_rank().over(w_cancel_rate))
)

restaurants_ranked.select(
    "restaurant_id", "restaurant_city",
    "avg_total_fulfillment_time_min", "orders_with_valid_time",
    "total_orders", "cancelled_orders", "cancellation_rate_pct",
    "rank_by_avg_fulfillment", "rank_by_cancellation_rate"
).orderBy(col("rank_by_avg_fulfillment").asc()).show(20, truncate=False)
# Out:
# +-------------+---------------+------------------------------+----------------------+------------+----------------+---------------------+-----------------------+-------------------------+
# |restaurant_id|restaurant_city|avg_total_fulfillment_time_min|orders_with_valid_time|total_orders|cancelled_orders|cancellation_rate_pct|rank_by_avg_fulfillment|rank_by_cancellation_rate|
# +-------------+---------------+------------------------------+----------------------+------------+----------------+---------------------+-----------------------+-------------------------+
# |R105         |Kolkata        |22.64                         |14                    |17          |6               |35.29                |1                      |147                      |
# |R171         |Hyderabad      |22.64                         |14                    |14          |6               |42.86                |1                      |177                      |
# |R116         |Pune           |24.0                          |9                     |11          |5               |45.45                |2                      |187                      |
# |R740         |Mumbai         |24.88                         |17                    |19          |5               |26.32                |3                      |108                      |
# |R902         |Kolkata        |25.0                          |17                    |19          |5               |26.32                |4                      |108                      |
# |R228         |Chennai        |25.69                         |16                    |20          |6               |30.0                 |5                      |125                      |
# |R425         |Pune           |25.87                         |15                    |19          |6               |31.58                |6                      |133                      |
# |R469         |Chennai        |26.06                         |17                    |18          |3               |16.67                |7                      |62                       |
# |R394         |Bangalore      |26.13                         |8                     |12          |1               |8.33                 |8                      |24                       |
# |R652         |Delhi          |26.15                         |20                    |24          |7               |29.17                |9                      |121                      |
# |R976         |Kolkata        |26.44                         |27                    |30          |12              |40.0                 |10                     |167                      |
# |R189         |Kolkata        |26.67                         |12                    |13          |4               |30.77                |11                     |129                      |
# |R218         |Chennai        |26.67                         |15                    |19          |7               |36.84                |11                     |154                      |
# |R263         |Pune           |26.92                         |12                    |15          |5               |33.33                |12                     |140                      |
# |R222         |Bangalore      |27.0                          |16                    |18          |5               |27.78                |13                     |115                      |
# |R873         |Delhi          |27.24                         |17                    |21          |6               |28.57                |14                     |118                      |
# |R478         |Hyderabad      |27.26                         |27                    |31          |7               |22.58                |15                     |90                       |
# |R755         |Mumbai         |27.31                         |16                    |19          |9               |47.37                |16                     |193                      |
# |R509         |Pune           |27.35                         |20                    |22          |8               |36.36                |17                     |152                      |
# |R194         |Hyderabad      |27.38                         |13                    |13          |3               |23.08                |18                     |93                       |
# +-------------+---------------+------------------------------+----------------------+------------+----------------+---------------------+-----------------------+-------------------------+
# only showing top 20 rows

# %% [markdown]
# # Rank delivery partners by:
# *   Fastest average delivery
# *   Highest ratings

# %%
partner_delivery_speed = (
    df.filter(gap_valid_filter)
      .groupBy("delivery_partner_id")
      .agg(
          spark_round(avg(col("delivery_time_gap_min")), 2).alias("avg_delivery_gap_min"),
          count(lit(1)).alias("orders_count_for_speed")
      )
)

# %%
partner_ratings = (
    df.filter((col("delivery_status") == "DELIVERED") & col("rating").isNotNull())
      .withColumn("rating_double", col("rating").cast("double"))
      .groupBy("delivery_partner_id")
      .agg(
          spark_round(avg(col("rating_double")), 2).alias("avg_rating"),
          count(lit(1)).alias("ratings_count")
      )
)

# %%
partners_joined = partner_delivery_speed.join(partner_ratings, on="delivery_partner_id", how="outer")

w_partner_speed  = Window.orderBy(col("avg_delivery_gap_min").asc())
w_partner_rating = Window.orderBy(col("avg_rating").desc())

partners_ranked = (
    partners_joined
      .withColumn("rank_fastest_delivery", dense_rank().over(w_partner_speed))
      .withColumn("rank_highest_rating",   dense_rank().over(w_partner_rating))
)

# %%
partners_ranked.select(
    "delivery_partner_id",
    "avg_delivery_gap_min", "orders_count_for_speed",
    "avg_rating", "ratings_count",
    "rank_fastest_delivery", "rank_highest_rating"
).orderBy(col("rank_fastest_delivery").asc(), col("rank_highest_rating").asc()).show(20, truncate=False)
# Out:
# +-------------------+--------------------+----------------------+----------+-------------+---------------------+-------------------+
# |delivery_partner_id|avg_delivery_gap_min|orders_count_for_speed|avg_rating|ratings_count|rank_fastest_delivery|rank_highest_rating|
# +-------------------+--------------------+----------------------+----------+-------------+---------------------+-------------------+
# |D267               |24.54               |119                   |3.21      |48           |1                    |25                 |
# |D417               |24.69               |104                   |3.36      |34           |2                    |10                 |
# |D246               |25.06               |122                   |3.02      |44           |3                    |44                 |
# |D570               |25.38               |130                   |2.86      |38           |4                    |60                 |
# |D111               |25.95               |112                   |3.01      |33           |5                    |45                 |
# |D108               |26.08               |114                   |3.06      |46           |6                    |40                 |
# |D955               |26.1                |110                   |2.92      |29           |7                    |54                 |
# |D564               |26.13               |102                   |2.78      |33           |8                    |68                 |
# |D452               |26.2                |124                   |2.86      |35           |9                    |60                 |
# |D294               |26.25               |118                   |2.85      |38           |10                   |61                 |
# |D918               |26.34               |102                   |2.99      |33           |11                   |47                 |
# |D841               |26.4                |131                   |3.15      |46           |12                   |31                 |
# |D619               |26.41               |113                   |2.89      |47           |13                   |57                 |
# |D874               |26.44               |126                   |2.96      |34           |14                   |50                 |
# |D187               |26.49               |124                   |2.78      |31           |15                   |68                 |
# |D696               |26.56               |115                   |3.22      |44           |16                   |24                 |
# |D790               |26.75               |105                   |2.96      |30           |17                   |50                 |
# |D242               |26.76               |119                   |2.77      |46           |18                   |69                 |
# |D664               |26.78               |105                   |2.97      |42           |19                   |49                 |
# |D695               |26.79               |131                   |3.31      |42           |20                   |15                 |
# +-------------------+--------------------+----------------------+----------+-------------+---------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
#  # Identify top 3 and bottom 3 per city

# %%
city_restaurant_perf = (
    df.filter(total_valid_filter & col("delivery_city").isNotNull())
      .groupBy("delivery_city", "restaurant_id", "restaurant_city")
      .agg(
          spark_round(avg(col("total_fulfillment_time_min")), 2).alias("avg_total_fulfillment_time_min"),
          count(lit(1)).alias("orders_with_valid_time")
      )
)

# %%
w_city_fast  = Window.partitionBy("delivery_city").orderBy(col("avg_total_fulfillment_time_min").asc())
w_city_slow  = Window.partitionBy("delivery_city").orderBy(col("avg_total_fulfillment_time_min").desc())

top3_per_city = city_restaurant_perf.withColumn("rank_in_city_fast", dense_rank().over(w_city_fast)) \
                                    .filter(col("rank_in_city_fast") <= 3) \
                                    .orderBy(col("delivery_city").asc(), col("rank_in_city_fast").asc())

bottom3_per_city = city_restaurant_perf.withColumn("rank_in_city_slow", dense_rank().over(w_city_slow)) \
                                       .filter(col("rank_in_city_slow") <= 3) \
                                       .orderBy(col("delivery_city").asc(), col("rank_in_city_slow").asc())

# %%
top3_per_city.select(
    "delivery_city", "restaurant_id", "restaurant_city",
    "avg_total_fulfillment_time_min", "orders_with_valid_time", "rank_in_city_fast"
).show(100, truncate=False)
# Out:
# +-------------+-------------+---------------+------------------------------+----------------------+-----------------+
# |delivery_city|restaurant_id|restaurant_city|avg_total_fulfillment_time_min|orders_with_valid_time|rank_in_city_fast|
# +-------------+-------------+---------------+------------------------------+----------------------+-----------------+
# |Bangalore    |R721         |Kolkata        |0.0                           |1                     |1                |
# |Bangalore    |R995         |Hyderabad      |0.0                           |1                     |1                |
# |Bangalore    |R548         |Bangalore      |0.0                           |1                     |1                |
# |Bangalore    |R322         |Delhi          |0.0                           |1                     |1                |
# |Bangalore    |R535         |Mumbai         |0.0                           |1                     |1                |
# |Bangalore    |R414         |Kolkata        |0.5                           |2                     |2                |
# |Bangalore    |R894         |Delhi          |1.0                           |1                     |3                |
# |Bangalore    |R885         |Bangalore      |1.0                           |1                     |3                |
# |Bangalore    |R729         |Kolkata        |1.0                           |1                     |3                |
# |Bangalore    |R819         |Kolkata        |1.0                           |1                     |3                |
# |Bangalore    |R323         |Bangalore      |1.0                           |1                     |3                |
# |Bangalore    |R471         |Bangalore      |1.0                           |1                     |3                |
# |Bangalore    |R837         |Delhi          |1.0                           |1                     |3                |
# |Bangalore    |R922         |Kolkata        |1.0                           |1                     |3                |
# |Bangalore    |R758         |Delhi          |1.0                           |1                     |3                |
# |Chennai      |R490         |Kolkata        |0.0                           |1                     |1                |
# |Chennai      |R812         |Delhi          |0.0                           |1                     |1                |
# |Chennai      |R765         |Kolkata        |0.0                           |1                     |1                |
# |Chennai      |R967         |Mumbai         |0.0                           |1                     |1                |
# |Chennai      |R622         |Kolkata        |0.0                           |1                     |1                |
# |Chennai      |R741         |Delhi          |1.0                           |1                     |2                |
# |Chennai      |R923         |Pune           |1.0                           |1                     |2                |
# |Chennai      |R788         |Chennai        |1.0                           |1                     |2                |
# |Chennai      |R513         |Kolkata        |2.0                           |1                     |3                |
# |Chennai      |R381         |Pune           |2.0                           |1                     |3                |
# |Chennai      |R171         |Mumbai         |2.0                           |1                     |3                |
# |Chennai      |R775         |Bangalore      |2.0                           |1                     |3                |
# |Chennai      |R392         |Chennai        |2.0                           |1                     |3                |
# |Chennai      |R423         |Chennai        |2.0                           |1                     |3                |
# |Chennai      |R899         |Chennai        |2.0                           |2                     |3                |
# |Chennai      |R834         |Hyderabad      |2.0                           |1                     |3                |
# |Delhi        |R528         |Mumbai         |0.0                           |1                     |1                |
# |Delhi        |R861         |Mumbai         |0.0                           |1                     |1                |
# |Delhi        |R923         |Chennai        |0.0                           |1                     |1                |
# |Delhi        |R336         |Bangalore      |0.0                           |1                     |1                |
# |Delhi        |R696         |Pune           |0.0                           |1                     |1                |
# |Delhi        |R950         |Hyderabad      |0.5                           |2                     |2                |
# |Delhi        |R205         |Hyderabad      |1.0                           |1                     |3                |
# |Delhi        |R962         |Delhi          |1.0                           |1                     |3                |
# |Delhi        |R356         |Chennai        |1.0                           |1                     |3                |
# |Hyderabad    |R222         |Mumbai         |0.0                           |1                     |1                |
# |Hyderabad    |R533         |Hyderabad      |0.0                           |1                     |1                |
# |Hyderabad    |R128         |Mumbai         |0.0                           |1                     |1                |
# |Hyderabad    |R968         |Mumbai         |1.0                           |1                     |2                |
# |Hyderabad    |R598         |Bangalore      |1.0                           |1                     |2                |
# |Hyderabad    |R973         |Delhi          |1.0                           |1                     |2                |
# |Hyderabad    |R269         |Chennai        |1.0                           |1                     |2                |
# |Hyderabad    |R777         |Mumbai         |1.0                           |1                     |2                |
# |Hyderabad    |R471         |Pune           |1.5                           |2                     |3                |
# |Kolkata      |R175         |Kolkata        |0.0                           |1                     |1                |
# |Kolkata      |R875         |Mumbai         |0.0                           |1                     |1                |
# |Kolkata      |R557         |Chennai        |0.0                           |1                     |1                |
# |Kolkata      |R809         |Mumbai         |0.0                           |1                     |1                |
# |Kolkata      |R608         |Delhi          |1.0                           |1                     |2                |
# |Kolkata      |R890         |Hyderabad      |1.0                           |1                     |2                |
# |Kolkata      |R867         |Hyderabad      |1.0                           |2                     |2                |
# |Kolkata      |R989         |Chennai        |1.0                           |1                     |2                |
# |Kolkata      |R220         |Bangalore      |1.0                           |1                     |2                |
# |Kolkata      |R121         |Pune           |1.0                           |1                     |2                |
# |Kolkata      |R255         |Bangalore      |1.0                           |1                     |2                |
# |Kolkata      |R443         |Hyderabad      |1.0                           |1                     |2                |
# |Kolkata      |R626         |Pune           |2.0                           |1                     |3                |
# |Kolkata      |R663         |Delhi          |2.0                           |1                     |3                |
# |Kolkata      |R600         |Chennai        |2.0                           |1                     |3                |
# |Kolkata      |R469         |Bangalore      |2.0                           |1                     |3                |
# |Kolkata      |R767         |Hyderabad      |2.0                           |1                     |3                |
# |Kolkata      |R515         |Delhi          |2.0                           |1                     |3                |
# |Mumbai       |R630         |Kolkata        |0.0                           |1                     |1                |
# |Mumbai       |R457         |Bangalore      |0.0                           |1                     |1                |
# |Mumbai       |R723         |Kolkata        |0.0                           |1                     |1                |
# |Mumbai       |R430         |Bangalore      |0.0                           |1                     |1                |
# |Mumbai       |R158         |Mumbai         |1.0                           |1                     |2                |
# |Mumbai       |R333         |Kolkata        |1.0                           |1                     |2                |
# |Mumbai       |R146         |Pune           |1.0                           |2                     |2                |
# |Mumbai       |R348         |Kolkata        |1.0                           |1                     |2                |
# |Mumbai       |R734         |Pune           |1.0                           |1                     |2                |
# |Mumbai       |R754         |Kolkata        |1.0                           |1                     |2                |
# |Mumbai       |R216         |Kolkata        |1.0                           |1                     |2                |
# |Mumbai       |R974         |Mumbai         |1.0                           |1                     |2                |
# |Mumbai       |R693         |Pune           |2.0                           |3                     |3                |
# |Mumbai       |R454         |Delhi          |2.0                           |3                     |3                |
# |Mumbai       |R759         |Pune           |2.0                           |1                     |3                |
# |Mumbai       |R538         |Pune           |2.0                           |1                     |3                |
# |Mumbai       |R998         |Delhi          |2.0                           |1                     |3                |
# |Mumbai       |R170         |Delhi          |2.0                           |1                     |3                |
# |Mumbai       |R422         |Delhi          |2.0                           |1                     |3                |
# |Mumbai       |R782         |Delhi          |2.0                           |1                     |3                |
# |Mumbai       |R553         |Delhi          |2.0                           |1                     |3                |
# |Mumbai       |R127         |Hyderabad      |2.0                           |1                     |3                |
# |Pune         |R222         |Chennai        |0.0                           |1                     |1                |
# |Pune         |R902         |Kolkata        |0.0                           |1                     |1                |
# |Pune         |R365         |Bangalore      |0.0                           |1                     |1                |
# |Pune         |R800         |Mumbai         |0.0                           |1                     |1                |
# |Pune         |R610         |Bangalore      |0.0                           |1                     |1                |
# |Pune         |R741         |Mumbai         |1.0                           |2                     |2                |
# |Pune         |R936         |Hyderabad      |1.0                           |1                     |2                |
# |Pune         |R527         |Delhi          |1.0                           |1                     |2                |
# |Pune         |R616         |Pune           |1.0                           |1                     |2                |
# |Pune         |R866         |Delhi          |1.5                           |2                     |3                |
# +-------------+-------------+---------------+------------------------------+----------------------+-----------------+

# %%
bottom3_per_city.select(
    "delivery_city", "restaurant_id", "restaurant_city",
    "avg_total_fulfillment_time_min", "orders_with_valid_time", "rank_in_city_slow"
).show(100, truncate=False)
# Out:
# +-------------+-------------+---------------+------------------------------+----------------------+-----------------+
# |delivery_city|restaurant_id|restaurant_city|avg_total_fulfillment_time_min|orders_with_valid_time|rank_in_city_slow|
# +-------------+-------------+---------------+------------------------------+----------------------+-----------------+
# |Bangalore    |R259         |Bangalore      |89.0                          |1                     |1                |
# |Bangalore    |R416         |Kolkata        |87.0                          |1                     |2                |
# |Bangalore    |R966         |Pune           |87.0                          |1                     |2                |
# |Bangalore    |R743         |Kolkata        |87.0                          |1                     |2                |
# |Bangalore    |R997         |Pune           |86.0                          |1                     |3                |
# |Chennai      |R296         |Bangalore      |88.0                          |1                     |1                |
# |Chennai      |R531         |Pune           |88.0                          |1                     |1                |
# |Chennai      |R661         |Pune           |88.0                          |1                     |1                |
# |Chennai      |R408         |Delhi          |86.0                          |1                     |2                |
# |Chennai      |R811         |Kolkata        |86.0                          |1                     |2                |
# |Chennai      |R103         |Delhi          |85.0                          |1                     |3                |
# |Chennai      |R705         |Kolkata        |85.0                          |1                     |3                |
# |Chennai      |R571         |Kolkata        |85.0                          |1                     |3                |
# |Chennai      |R800         |Chennai        |85.0                          |1                     |3                |
# |Chennai      |R217         |Mumbai         |85.0                          |1                     |3                |
# |Delhi        |R129         |Pune           |88.0                          |1                     |1                |
# |Delhi        |R952         |Bangalore      |87.0                          |1                     |2                |
# |Delhi        |R227         |Chennai        |86.0                          |1                     |3                |
# |Hyderabad    |R218         |Kolkata        |88.0                          |1                     |1                |
# |Hyderabad    |R509         |Hyderabad      |88.0                          |1                     |1                |
# |Hyderabad    |R487         |Hyderabad      |87.0                          |1                     |2                |
# |Hyderabad    |R315         |Chennai        |86.0                          |1                     |3                |
# |Hyderabad    |R902         |Mumbai         |86.0                          |1                     |3                |
# |Hyderabad    |R316         |Kolkata        |86.0                          |1                     |3                |
# |Hyderabad    |R146         |Chennai        |86.0                          |1                     |3                |
# |Hyderabad    |R871         |Hyderabad      |86.0                          |1                     |3                |
# |Hyderabad    |R616         |Pune           |86.0                          |1                     |3                |
# |Kolkata      |R528         |Bangalore      |89.0                          |1                     |1                |
# |Kolkata      |R813         |Delhi          |89.0                          |1                     |1                |
# |Kolkata      |R321         |Bangalore      |88.0                          |1                     |2                |
# |Kolkata      |R872         |Hyderabad      |88.0                          |1                     |2                |
# |Kolkata      |R965         |Bangalore      |87.0                          |1                     |3                |
# |Mumbai       |R769         |Mumbai         |89.0                          |1                     |1                |
# |Mumbai       |R559         |Chennai        |88.0                          |1                     |2                |
# |Mumbai       |R838         |Delhi          |87.0                          |1                     |3                |
# |Pune         |R727         |Bangalore      |90.0                          |1                     |1                |
# |Pune         |R313         |Chennai        |89.0                          |1                     |2                |
# |Pune         |R488         |Hyderabad      |88.0                          |1                     |3                |
# |Pune         |R896         |Mumbai         |88.0                          |1                     |3                |
# |Pune         |R512         |Bangalore      |88.0                          |1                     |3                |
# +-------------+-------------+---------------+------------------------------+----------------------+-----------------+

# %% [markdown]
# # PHASE 7 – Customer Experience

# %%
from pyspark.sql.functions import col

delivered = (
    df.filter((col("delivery_status") == "DELIVERED") & col("rating").isNotNull())).withColumn("rating_double", col("rating").cast("double"))

delivered_total = delivered.filter(
    col("total_fulfillment_time_min").isNotNull() & ~col("total_fulfillment_time_negative")
)

delivered_gap = delivered.filter(
    col("delivery_time_gap_min").isNotNull() & ~col("delivery_time_gap_negative")
)

# %% [markdown]
# # Average rating per restaurant

# %%
from pyspark.sql.functions import avg, round as spark_round, count, desc

avg_rating_per_restaurant = (
    delivered.groupBy("restaurant_id", "restaurant_city")
    .agg(
        spark_round(avg("rating_double"), 2).alias("avg_rating"),
        count("*").alias("delivered_count")
    )
    .orderBy(desc("avg_rating"), desc("delivered_count"))
)

avg_rating_per_restaurant.show(30, truncate=False)
# Out:
# +-------------+---------------+----------+---------------+
# |restaurant_id|restaurant_city|avg_rating|delivered_count|
# +-------------+---------------+----------+---------------+
# |R660         |Chennai        |4.95      |2              |
# |R641         |Delhi          |4.9       |1              |
# |R768         |Chennai        |4.9       |1              |
# |R789         |Hyderabad      |4.9       |1              |
# |R806         |Hyderabad      |4.9       |1              |
# |R420         |Pune           |4.9       |1              |
# |R864         |Pune           |4.9       |1              |
# |R746         |Hyderabad      |4.85      |2              |
# |R209         |Hyderabad      |4.8       |2              |
# |R922         |Mumbai         |4.8       |1              |
# |R486         |Bangalore      |4.8       |1              |
# |R514         |Bangalore      |4.8       |1              |
# |R166         |Pune           |4.7       |2              |
# |R961         |Delhi          |4.7       |1              |
# |R752         |Chennai        |4.67      |3              |
# |R651         |Delhi          |4.65      |2              |
# |R905         |Mumbai         |4.64      |5              |
# |R998         |Chennai        |4.63      |4              |
# |R533         |Chennai        |4.6       |4              |
# |R951         |Kolkata        |4.6       |2              |
# |R862         |Delhi          |4.6       |1              |
# |R529         |Pune           |4.6       |1              |
# |R803         |Pune           |4.58      |5              |
# |R751         |Chennai        |4.55      |4              |
# |R652         |Delhi          |4.55      |2              |
# |R127         |Pune           |4.55      |2              |
# |R930         |Kolkata        |4.55      |2              |
# |R759         |Bangalore      |4.53      |3              |
# |R372         |Chennai        |4.53      |3              |
# |R443         |Bangalore      |4.52      |6              |
# +-------------+---------------+----------+---------------+
# only showing top 30 rows

# %% [markdown]
# # Relationship between:
# *   Delivery time
# *   Rating

# %%
from pyspark.sql.functions import corr

delivered_total.agg(
    corr("total_fulfillment_time_min", "rating_double").alias("corr_total_vs_rating")
).show()

delivered_gap.agg(
    corr("delivery_time_gap_min", "rating_double").alias("corr_gap_vs_rating")
).show()
# Out:
# +--------------------+
# |corr_total_vs_rating|
# +--------------------+
# |-6.13801103559660...|
# +--------------------+
#
# +--------------------+
# |  corr_gap_vs_rating|
# +--------------------+
# |-0.00185129337774...|
# +--------------------+

# %% [markdown]
# #  Identify if slower deliveries reduce ratings

# %%
q25, q50, q75 = delivered_total.approxQuantile("total_fulfillment_time_min", [0.25, 0.5, 0.75], 0.01)


fast_vs_slow = (
    delivered_total
    .withColumn(
        "speed_bucket",
        when(col("total_fulfillment_time_min") <= q25, "FAST (<= P25)")
        .when(col("total_fulfillment_time_min") >= q75, "SLOW (>= P75)")
        .otherwise(None)
    )
    .filter(col("speed_bucket").isNotNull())
    .groupBy("speed_bucket")
    .agg(
        spark_round(avg("rating_double"), 2).alias("avg_rating"),
        count("*").alias("orders")
    )
    .orderBy("speed_bucket")
)

fast_vs_slow.show(truncate=False)
# Out:
# +-------------+----------+------+
# |speed_bucket |avg_rating|orders|
# +-------------+----------+------+
# |FAST (<= P25)|3.0       |8686  |
# |SLOW (>= P75)|2.99      |8618  |
# +-------------+----------+------+

# %% [markdown]
# # PHASE 8 – Performance Engineering

# %% [markdown]
# # Cache the cleaned DataFrame

# %%
df_cached = df.cache()

# %% [markdown]
# # Use explain(True) on:
# *   Restaurant ranking query
# *   City delay analysis query

# %%
restaurant_time_agg = (
    df_cached.filter(total_valid_filter)
             .groupBy("restaurant_id", "restaurant_city")
             .agg(
                 spark_round(avg(col("total_fulfillment_time_min")), 2).alias("avg_total_fulfillment_time_min"),
                 count("*").alias("orders_with_valid_time")
             )
)

restaurant_cancel_agg = (
    df_cached.groupBy("restaurant_id", "restaurant_city")
             .agg(
                 count("*").alias("total_orders"),
                 spark_sum(when(col("delivery_status") == "CANCELLED", 1).otherwise(0)).alias("cancelled_orders")
             )
             .withColumn("cancellation_rate_pct",
                         spark_round((col("cancelled_orders") / col("total_orders")) * 100.0, 2))
)

restaurants_ranked_q = (
    restaurant_time_agg.join(restaurant_cancel_agg, ["restaurant_id", "restaurant_city"], "outer")
                       .withColumn("rank_by_avg_fulfillment",
                                   dense_rank().over(Window.orderBy(col("avg_total_fulfillment_time_min").asc())))
                       .withColumn("rank_by_cancellation_rate",
                                   dense_rank().over(Window.orderBy(col("cancellation_rate_pct").asc())))
)

avg_gap_per_city_q = (
    df_cached.filter(gap_valid_filter)
             .groupBy("delivery_city")
             .agg(
                 spark_round(avg(col("delivery_time_gap_min")), 2).alias("avg_delivery_time_gap_min"),
                 count("*").alias("orders_count")
             )
)

# %%
print("Restaurant Ranking Query")
restaurants_ranked_q.explain(True)
# Out:
# Restaurant Ranking Query
# == Parsed Logical Plan ==
# 'Project [unresolvedstarwithcolumns(rank_by_cancellation_rate, 'dense_rank() windowspecdefinition('cancellation_rate_pct ASC NULLS FIRST, unspecifiedframe$()), None)]
# +- Project [restaurant_id#8745, restaurant_city#8746, avg_total_fulfillment_time_min#8640, orders_with_valid_time#8641L, total_orders#8671L, cancelled_orders#8672L, cancellation_rate_pct#8702, rank_by_avg_fulfillment#8747]
#    +- Project [restaurant_id#8745, restaurant_city#8746, avg_total_fulfillment_time_min#8640, orders_with_valid_time#8641L, total_orders#8671L, cancelled_orders#8672L, cancellation_rate_pct#8702, rank_by_avg_fulfillment#8747, rank_by_avg_fulfillment#8747]
#       +- Window [dense_rank(avg_total_fulfillment_time_min#8640) windowspecdefinition(avg_total_fulfillment_time_min#8640 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rank_by_avg_fulfillment#8747], [avg_total_fulfillment_time_min#8640 ASC NULLS FIRST]
#          +- Project [restaurant_id#8745, restaurant_city#8746, avg_total_fulfillment_time_min#8640, orders_with_valid_time#8641L, total_orders#8671L, cancelled_orders#8672L, cancellation_rate_pct#8702]
#             +- Project [coalesce(restaurant_id#6813, restaurant_id#8718) AS restaurant_id#8745, coalesce(restaurant_city#6814, restaurant_city#8719) AS restaurant_city#8746, avg_total_fulfillment_time_min#8640, orders_with_valid_time#8641L, total_orders#8671L, cancelled_orders#8672L, cancellation_rate_pct#8702]
#                +- Join FullOuter, ((restaurant_id#6813 = restaurant_id#8718) AND (restaurant_city#6814 = restaurant_city#8719))
#                   :- Aggregate [restaurant_id#6813, restaurant_city#6814], [restaurant_id#6813, restaurant_city#6814, round(avg(total_fulfillment_time_min#6966), 2) AS avg_total_fulfillment_time_min#8640, count(1) AS orders_with_valid_time#8641L]
#                   :  +- Filter (isnotnull(total_fulfillment_time_min#6966) AND NOT total_fulfillment_time_negative#6969)
#                   :     +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6970, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS delivery_time_gap_min#6971, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#                   :        +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS prep_time_min#6970, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#                   :           +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#                   :              +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 1 more fields]
#                   :                 +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, CASE WHEN isnull(prep_time_min#6964) THEN false ELSE (prep_time_min#6964 < cast(0 as double)) END AS prep_time_negative#6967]
#                   :                    +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS total_fulfillment_time_min#6966]
#                   :                       +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS delivery_time_gap_min#6965]
#                   :                          +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS prep_time_min#6964]
#                   :                             +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, isnotnull(delivery_time_clean#6847) AS delivery_time_valid#6850]
#                   :                                +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, isnotnull(pickup_time_clean#6846) AS pickup_time_valid#6849]
#                   :                                   +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, isnotnull(order_time_clean#6845) AS order_time_valid#6848]
#                   :                                      +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, coalesce(try_to_timestamp(CASE WHEN isnull(delivery_time#6626) THEN cast(null as string) WHEN (trim(delivery_time#6626, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#6626, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(delivery_time#6626) THEN cast(null as string) WHEN (trim(delivery_time#6626, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#6626, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(delivery_time#6626) THEN cast(null as string) WHEN (trim(delivery_time#6626, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#6626, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS delivery_time_clean#6847]
#                   :                                         +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, coalesce(try_to_timestamp(CASE WHEN isnull(pickup_time#6625) THEN cast(null as string) WHEN (trim(pickup_time#6625, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#6625, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(pickup_time#6625) THEN cast(null as string) WHEN (trim(pickup_time#6625, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#6625, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(pickup_time#6625) THEN cast(null as string) WHEN (trim(pickup_time#6625, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#6625, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS pickup_time_clean#6846]
#                   :                                            +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, coalesce(try_to_timestamp(CASE WHEN isnull(order_time#6624) THEN cast(null as string) WHEN (trim(order_time#6624, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#6624, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#6624, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(order_time#6624) THEN cast(null as string) WHEN (trim(order_time#6624, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#6624, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#6624, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(order_time#6624) THEN cast(null as string) WHEN (trim(order_time#6624, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#6624, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#6624, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS order_time_clean#6845]
#                   :                                               +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825]
#                   :                                                  +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_nocommas#6822, order_amount_clean#6824, isnotnull(order_amount_clean#6824) AS order_amount_valid#6825]
#                   :                                                     +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_nocommas#6822, CASE WHEN (order_amount_clean#6823 < 0) THEN cast(null as int) ELSE order_amount_clean#6823 END AS order_amount_clean#6824]
#                   :                                                        +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_nocommas#6822, CASE WHEN RLIKE(order_amount_nocommas#6822, ^\d+$) THEN cast(order_amount_nocommas#6822 as int) ELSE cast(null as int) END AS order_amount_clean#6823]
#                   :                                                           +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, regexp_replace(order_amount#6818, ,, , 1) AS order_amount_nocommas#6822]
#                   :                                                              +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, CASE WHEN (isnull(rating#6631) OR (trim(rating#6631, None) = )) THEN cast(null as string) ELSE trim(rating#6631, None) END AS rating#6820]
#                   :                                                                 +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, CASE WHEN (isnull(payment_mode#6630) OR (trim(payment_mode#6630, None) = )) THEN cast(null as string) ELSE trim(payment_mode#6630, None) END AS payment_mode#6819, rating#6631]
#                   :                                                                    +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, CASE WHEN (isnull(order_amount#6629) OR (trim(order_amount#6629, None) = )) THEN cast(null as string) ELSE trim(order_amount#6629, None) END AS order_amount#6818, payment_mode#6630, rating#6631]
#                   :                                                                       +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, CASE WHEN (isnull(delivery_partner_id#6628) OR (trim(delivery_partner_id#6628, None) = )) THEN cast(null as string) ELSE trim(delivery_partner_id#6628, None) END AS delivery_partner_id#6817, order_amount#6629, payment_mode#6630, rating#6631]
#                   :                                                                          +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, CASE WHEN (isnull(delivery_status#6627) OR (trim(delivery_status#6627, None) = )) THEN cast(null as string) ELSE trim(delivery_status#6627, None) END AS delivery_status#6816, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                   :                                                                             +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, CASE WHEN (isnull(delivery_city#6623) OR (trim(delivery_city#6623, None) = )) THEN cast(null as string) ELSE trim(delivery_city#6623, None) END AS delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                   :                                                                                +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, CASE WHEN (isnull(restaurant_city#6622) OR (trim(restaurant_city#6622, None) = )) THEN cast(null as string) ELSE trim(restaurant_city#6622, None) END AS restaurant_city#6814, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                   :                                                                                   +- Project [order_id#6811, customer_id#6812, CASE WHEN (isnull(restaurant_id#6621) OR (trim(restaurant_id#6621, None) = )) THEN cast(null as string) ELSE trim(restaurant_id#6621, None) END AS restaurant_id#6813, restaurant_city#6622, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                   :                                                                                      +- Project [order_id#6811, CASE WHEN (isnull(customer_id#6620) OR (trim(customer_id#6620, None) = )) THEN cast(null as string) ELSE trim(customer_id#6620, None) END AS customer_id#6812, restaurant_id#6621, restaurant_city#6622, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                   :                                                                                         +- Project [CASE WHEN (isnull(order_id#6619) OR (trim(order_id#6619, None) = )) THEN cast(null as string) ELSE trim(order_id#6619, None) END AS order_id#6811, customer_id#6620, restaurant_id#6621, restaurant_city#6622, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                   :                                                                                            +- Relation [order_id#6619,customer_id#6620,restaurant_id#6621,restaurant_city#6622,delivery_city#6623,order_time#6624,pickup_time#6625,delivery_time#6626,delivery_status#6627,delivery_partner_id#6628,order_amount#6629,payment_mode#6630,rating#6631] csv
#                   +- Project [restaurant_id#8718, restaurant_city#8719, total_orders#8671L, cancelled_orders#8672L, round(((cast(cancelled_orders#8672L as double) / cast(total_orders#8671L as double)) * 100.0), 2) AS cancellation_rate_pct#8702]
#                      +- Aggregate [restaurant_id#8718, restaurant_city#8719], [restaurant_id#8718, restaurant_city#8719, count(1) AS total_orders#8671L, sum(CASE WHEN (delivery_status#8721 = CANCELLED) THEN 1 ELSE 0 END) AS cancelled_orders#8672L]
#                         +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_clean#8728, order_amount_valid#8729, order_time_clean#8730, pickup_time_clean#8731, delivery_time_clean#8732, order_time_valid#8733, pickup_time_valid#8734, delivery_time_valid#8735, prep_time_min#8742, CASE WHEN (isnotnull(delivery_time_clean#8732) AND isnotnull(pickup_time_clean#8731)) THEN (cast((cast(delivery_time_clean#8732 as bigint) - cast(pickup_time_clean#8731 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS delivery_time_gap_min#8743, total_fulfillment_time_min#8738, prep_time_negative#8739, ... 2 more fields]
#                            +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_clean#8728, order_amount_valid#8729, order_time_clean#8730, pickup_time_clean#8731, delivery_time_clean#8732, order_time_valid#8733, pickup_time_valid#8734, delivery_time_valid#8735, CASE WHEN (isnotnull(pickup_time_clean#8731) AND isnotnull(order_time_clean#8730)) THEN (cast((cast(pickup_time_clean#8731 as bigint) - cast(order_time_clean#8730 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS prep_time_min#8742, delivery_time_gap_min#8737, total_fulfillment_time_min#8738, prep_time_negative#8739, ... 2 more fields]
#                               +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_clean#8728, order_amount_valid#8729, order_time_clean#8730, pickup_time_clean#8731, delivery_time_clean#8732, order_time_valid#8733, pickup_time_valid#8734, delivery_time_valid#8735, prep_time_min#8736, delivery_time_gap_min#8737, total_fulfillment_time_min#8738, prep_time_negative#8739, ... 2 more fields]
#                                  +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_clean#8728, order_amount_valid#8729, order_time_clean#8730, pickup_time_clean#8731, delivery_time_clean#8732, order_time_valid#8733, pickup_time_valid#8734, delivery_time_valid#8735, prep_time_min#8736, delivery_time_gap_min#8737, total_fulfillment_time_min#8738, prep_time_negative#8739, ... 1 more fields]
#                                     +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_clean#8728, order_amount_valid#8729, order_time_clean#8730, pickup_time_clean#8731, delivery_time_clean#8732, order_time_valid#8733, pickup_time_valid#8734, delivery_time_valid#8735, prep_time_min#8736, delivery_time_gap_min#8737, total_fulfillment_time_min#8738, CASE WHEN isnull(prep_time_min#8736) THEN false ELSE (prep_time_min#8736 < cast(0 as double)) END AS prep_time_negative#8739]
#                                        +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_clean#8728, order_amount_valid#8729, order_time_clean#8730, pickup_time_clean#8731, delivery_time_clean#8732, order_time_valid#8733, pickup_time_valid#8734, delivery_time_valid#8735, prep_time_min#8736, delivery_time_gap_min#8737, CASE WHEN (isnotnull(delivery_time_clean#8732) AND isnotnull(order_time_clean#8730)) THEN (cast((cast(delivery_time_clean#8732 as bigint) - cast(order_time_clean#8730 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS total_fulfillment_time_min#8738]
#                                           +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_clean#8728, order_amount_valid#8729, order_time_clean#8730, pickup_time_clean#8731, delivery_time_clean#8732, order_time_valid#8733, pickup_time_valid#8734, delivery_time_valid#8735, prep_time_min#8736, CASE WHEN (isnotnull(delivery_time_clean#8732) AND isnotnull(pickup_time_clean#8731)) THEN (cast((cast(delivery_time_clean#8732 as bigint) - cast(pickup_time_clean#8731 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS delivery_time_gap_min#8737]
#                                              +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_clean#8728, order_amount_valid#8729, order_time_clean#8730, pickup_time_clean#8731, delivery_time_clean#8732, order_time_valid#8733, pickup_time_valid#8734, delivery_time_valid#8735, CASE WHEN (isnotnull(pickup_time_clean#8731) AND isnotnull(order_time_clean#8730)) THEN (cast((cast(pickup_time_clean#8731 as bigint) - cast(order_time_clean#8730 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS prep_time_min#8736]
#                                                 +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_clean#8728, order_amount_valid#8729, order_time_clean#8730, pickup_time_clean#8731, delivery_time_clean#8732, order_time_valid#8733, pickup_time_valid#8734, isnotnull(delivery_time_clean#8732) AS delivery_time_valid#8735]
#                                                    +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_clean#8728, order_amount_valid#8729, order_time_clean#8730, pickup_time_clean#8731, delivery_time_clean#8732, order_time_valid#8733, isnotnull(pickup_time_clean#8731) AS pickup_time_valid#8734]
#                                                       +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_clean#8728, order_amount_valid#8729, order_time_clean#8730, pickup_time_clean#8731, delivery_time_clean#8732, isnotnull(order_time_clean#8730) AS order_time_valid#8733]
#                                                          +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_clean#8728, order_amount_valid#8729, order_time_clean#8730, pickup_time_clean#8731, coalesce(try_to_timestamp(CASE WHEN isnull(delivery_time#8710) THEN cast(null as string) WHEN (trim(delivery_time#8710, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#8710, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#8710, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(delivery_time#8710) THEN cast(null as string) WHEN (trim(delivery_time#8710, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#8710, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#8710, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(delivery_time#8710) THEN cast(null as string) WHEN (trim(delivery_time#8710, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#8710, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#8710, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS delivery_time_clean#8732]
#                                                             +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_clean#8728, order_amount_valid#8729, order_time_clean#8730, coalesce(try_to_timestamp(CASE WHEN isnull(pickup_time#8709) THEN cast(null as string) WHEN (trim(pickup_time#8709, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#8709, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#8709, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(pickup_time#8709) THEN cast(null as string) WHEN (trim(pickup_time#8709, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#8709, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#8709, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(pickup_time#8709) THEN cast(null as string) WHEN (trim(pickup_time#8709, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#8709, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#8709, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS pickup_time_clean#8731]
#                                                                +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_clean#8728, order_amount_valid#8729, coalesce(try_to_timestamp(CASE WHEN isnull(order_time#8708) THEN cast(null as string) WHEN (trim(order_time#8708, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#8708, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#8708, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(order_time#8708) THEN cast(null as string) WHEN (trim(order_time#8708, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#8708, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#8708, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(order_time#8708) THEN cast(null as string) WHEN (trim(order_time#8708, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#8708, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#8708, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS order_time_clean#8730]
#                                                                   +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_clean#8728, order_amount_valid#8729]
#                                                                      +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_nocommas#8726, order_amount_clean#8728, isnotnull(order_amount_clean#8728) AS order_amount_valid#8729]
#                                                                         +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_nocommas#8726, CASE WHEN (order_amount_clean#8727 < 0) THEN cast(null as int) ELSE order_amount_clean#8727 END AS order_amount_clean#8728]
#                                                                            +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_nocommas#8726, CASE WHEN RLIKE(order_amount_nocommas#8726, ^\d+$) THEN cast(order_amount_nocommas#8726 as int) ELSE cast(null as int) END AS order_amount_clean#8727]
#                                                                               +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, regexp_replace(order_amount#8723, ,, , 1) AS order_amount_nocommas#8726]
#                                                                                  +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, CASE WHEN (isnull(rating#8715) OR (trim(rating#8715, None) = )) THEN cast(null as string) ELSE trim(rating#8715, None) END AS rating#8725]
#                                                                                     +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, CASE WHEN (isnull(payment_mode#8714) OR (trim(payment_mode#8714, None) = )) THEN cast(null as string) ELSE trim(payment_mode#8714, None) END AS payment_mode#8724, rating#8715]
#                                                                                        +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, CASE WHEN (isnull(order_amount#8713) OR (trim(order_amount#8713, None) = )) THEN cast(null as string) ELSE trim(order_amount#8713, None) END AS order_amount#8723, payment_mode#8714, rating#8715]
#                                                                                           +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, CASE WHEN (isnull(delivery_partner_id#8712) OR (trim(delivery_partner_id#8712, None) = )) THEN cast(null as string) ELSE trim(delivery_partner_id#8712, None) END AS delivery_partner_id#8722, order_amount#8713, payment_mode#8714, rating#8715]
#                                                                                              +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, CASE WHEN (isnull(delivery_status#8711) OR (trim(delivery_status#8711, None) = )) THEN cast(null as string) ELSE trim(delivery_status#8711, None) END AS delivery_status#8721, delivery_partner_id#8712, order_amount#8713, payment_mode#8714, rating#8715]
#                                                                                                 +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, CASE WHEN (isnull(delivery_city#8707) OR (trim(delivery_city#8707, None) = )) THEN cast(null as string) ELSE trim(delivery_city#8707, None) END AS delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8711, delivery_partner_id#8712, order_amount#8713, payment_mode#8714, rating#8715]
#                                                                                                    +- Project [order_id#8716, customer_id#8717, restaurant_id#8718, CASE WHEN (isnull(restaurant_city#8706) OR (trim(restaurant_city#8706, None) = )) THEN cast(null as string) ELSE trim(restaurant_city#8706, None) END AS restaurant_city#8719, delivery_city#8707, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8711, delivery_partner_id#8712, order_amount#8713, payment_mode#8714, rating#8715]
#                                                                                                       +- Project [order_id#8716, customer_id#8717, CASE WHEN (isnull(restaurant_id#8705) OR (trim(restaurant_id#8705, None) = )) THEN cast(null as string) ELSE trim(restaurant_id#8705, None) END AS restaurant_id#8718, restaurant_city#8706, delivery_city#8707, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8711, delivery_partner_id#8712, order_amount#8713, payment_mode#8714, rating#8715]
#                                                                                                          +- Project [order_id#8716, CASE WHEN (isnull(customer_id#8704) OR (trim(customer_id#8704, None) = )) THEN cast(null as string) ELSE trim(customer_id#8704, None) END AS customer_id#8717, restaurant_id#8705, restaurant_city#8706, delivery_city#8707, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8711, delivery_partner_id#8712, order_amount#8713, payment_mode#8714, rating#8715]
#                                                                                                             +- Project [CASE WHEN (isnull(order_id#8703) OR (trim(order_id#8703, None) = )) THEN cast(null as string) ELSE trim(order_id#8703, None) END AS order_id#8716, customer_id#8704, restaurant_id#8705, restaurant_city#8706, delivery_city#8707, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8711, delivery_partner_id#8712, order_amount#8713, payment_mode#8714, rating#8715]
#                                                                                                                +- Relation [order_id#8703,customer_id#8704,restaurant_id#8705,restaurant_city#8706,delivery_city#8707,order_time#8708,pickup_time#8709,delivery_time#8710,delivery_status#8711,delivery_partner_id#8712,order_amount#8713,payment_mode#8714,rating#8715] csv
#
# == Analyzed Logical Plan ==
# restaurant_id: string, restaurant_city: string, avg_total_fulfillment_time_min: double, orders_with_valid_time: bigint, total_orders: bigint, cancelled_orders: bigint, cancellation_rate_pct: double, rank_by_avg_fulfillment: int, rank_by_cancellation_rate: int
# Project [restaurant_id#8745, restaurant_city#8746, avg_total_fulfillment_time_min#8640, orders_with_valid_time#8641L, total_orders#8671L, cancelled_orders#8672L, cancellation_rate_pct#8702, rank_by_avg_fulfillment#8747, rank_by_cancellation_rate#8756]
# +- Project [restaurant_id#8745, restaurant_city#8746, avg_total_fulfillment_time_min#8640, orders_with_valid_time#8641L, total_orders#8671L, cancelled_orders#8672L, cancellation_rate_pct#8702, rank_by_avg_fulfillment#8747, rank_by_cancellation_rate#8756, rank_by_cancellation_rate#8756]
#    +- Window [dense_rank(cancellation_rate_pct#8702) windowspecdefinition(cancellation_rate_pct#8702 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rank_by_cancellation_rate#8756], [cancellation_rate_pct#8702 ASC NULLS FIRST]
#       +- Project [restaurant_id#8745, restaurant_city#8746, avg_total_fulfillment_time_min#8640, orders_with_valid_time#8641L, total_orders#8671L, cancelled_orders#8672L, cancellation_rate_pct#8702, rank_by_avg_fulfillment#8747]
#          +- Project [restaurant_id#8745, restaurant_city#8746, avg_total_fulfillment_time_min#8640, orders_with_valid_time#8641L, total_orders#8671L, cancelled_orders#8672L, cancellation_rate_pct#8702, rank_by_avg_fulfillment#8747]
#             +- Project [restaurant_id#8745, restaurant_city#8746, avg_total_fulfillment_time_min#8640, orders_with_valid_time#8641L, total_orders#8671L, cancelled_orders#8672L, cancellation_rate_pct#8702, rank_by_avg_fulfillment#8747, rank_by_avg_fulfillment#8747]
#                +- Window [dense_rank(avg_total_fulfillment_time_min#8640) windowspecdefinition(avg_total_fulfillment_time_min#8640 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rank_by_avg_fulfillment#8747], [avg_total_fulfillment_time_min#8640 ASC NULLS FIRST]
#                   +- Project [restaurant_id#8745, restaurant_city#8746, avg_total_fulfillment_time_min#8640, orders_with_valid_time#8641L, total_orders#8671L, cancelled_orders#8672L, cancellation_rate_pct#8702]
#                      +- Project [coalesce(restaurant_id#6813, restaurant_id#8718) AS restaurant_id#8745, coalesce(restaurant_city#6814, restaurant_city#8719) AS restaurant_city#8746, avg_total_fulfillment_time_min#8640, orders_with_valid_time#8641L, total_orders#8671L, cancelled_orders#8672L, cancellation_rate_pct#8702]
#                         +- Join FullOuter, ((restaurant_id#6813 = restaurant_id#8718) AND (restaurant_city#6814 = restaurant_city#8719))
#                            :- Aggregate [restaurant_id#6813, restaurant_city#6814], [restaurant_id#6813, restaurant_city#6814, round(avg(total_fulfillment_time_min#6966), 2) AS avg_total_fulfillment_time_min#8640, count(1) AS orders_with_valid_time#8641L]
#                            :  +- Filter (isnotnull(total_fulfillment_time_min#6966) AND NOT total_fulfillment_time_negative#6969)
#                            :     +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6970, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS delivery_time_gap_min#6971, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#                            :        +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS prep_time_min#6970, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#                            :           +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#                            :              +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 1 more fields]
# ...
#                      :                                      +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, CASE WHEN (order_amount_clean#6823 < 0) THEN null ELSE order_amount_clean#6823 END AS order_amount_clean#6824]
#                      :                                         +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, CASE WHEN RLIKE(order_amount_nocommas#6822, ^\d+$) THEN cast(order_amount_nocommas#6822 as int) END AS order_amount_clean#6823]
#                      :                                            +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, regexp_replace(order_amount#6818, ,, , 1) AS order_amount_nocommas#6822]
#                      :                                               +- *(1) Project [CASE WHEN (isnull(order_id#6619) OR (trim(order_id#6619, None) = )) THEN null ELSE trim(order_id#6619, None) END AS order_id#6811, CASE WHEN (isnull(customer_id#6620) OR (trim(customer_id#6620, None) = )) THEN null ELSE trim(customer_id#6620, None) END AS customer_id#6812, CASE WHEN (isnull(restaurant_id#6621) OR (trim(restaurant_id#6621, None) = )) THEN null ELSE trim(restaurant_id#6621, None) END AS restaurant_id#6813, CASE WHEN (isnull(restaurant_city#6622) OR (trim(restaurant_city#6622, None) = )) THEN null ELSE trim(restaurant_city#6622, None) END AS restaurant_city#6814, CASE WHEN (isnull(delivery_city#6623) OR (trim(delivery_city#6623, None) = )) THEN null ELSE trim(delivery_city#6623, None) END AS delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, CASE WHEN (isnull(delivery_status#6627) OR (trim(delivery_status#6627, None) = )) THEN null ELSE trim(delivery_status#6627, None) END AS delivery_status#6816, CASE WHEN (isnull(delivery_partner_id#6628) OR (trim(delivery_partner_id#6628, None) = )) THEN null ELSE trim(delivery_partner_id#6628, None) END AS delivery_partner_id#6817, CASE WHEN (isnull(order_amount#6629) OR (trim(order_amount#6629, None) = )) THEN null ELSE trim(order_amount#6629, None) END AS order_amount#6818, CASE WHEN (isnull(payment_mode#6630) OR (trim(payment_mode#6630, None) = )) THEN null ELSE trim(payment_mode#6630, None) END AS payment_mode#6819, CASE WHEN (isnull(rating#6631) OR (trim(rating#6631, None) = )) THEN null ELSE trim(rating#6631, None) END AS rating#6820]
#                      :                                                  +- FileScan csv [order_id#6619,customer_id#6620,restaurant_id#6621,restaurant_city#6622,delivery_city#6623,order_time#6624,pickup_time#6625,delivery_time#6626,delivery_status#6627,delivery_partner_id#6628,order_amount#6629,payment_mode#6630,rating#6631] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/delivery_data.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<order_id:string,customer_id:string,restaurant_id:string,restaurant_city:string,delivery_ci...
#                      +- Sort [restaurant_id#8718 ASC NULLS FIRST, restaurant_city#8719 ASC NULLS FIRST], false, 0
#                         +- Project [restaurant_id#8718, restaurant_city#8719, total_orders#8671L, cancelled_orders#8672L, round(((cast(cancelled_orders#8672L as double) / cast(total_orders#8671L as double)) * 100.0), 2) AS cancellation_rate_pct#8702]
#                            +- HashAggregate(keys=[restaurant_id#8718, restaurant_city#8719], functions=[count(1), sum(CASE WHEN (delivery_status#8721 = CANCELLED) THEN 1 ELSE 0 END)], output=[restaurant_id#8718, restaurant_city#8719, total_orders#8671L, cancelled_orders#8672L])
#                               +- Exchange hashpartitioning(restaurant_id#8718, restaurant_city#8719, 200), ENSURE_REQUIREMENTS, [plan_id=5906]
#                                  +- HashAggregate(keys=[restaurant_id#8718, restaurant_city#8719], functions=[partial_count(1), partial_sum(CASE WHEN (delivery_status#8721 = CANCELLED) THEN 1 ELSE 0 END)], output=[restaurant_id#8718, restaurant_city#8719, count#9626L, sum#9627L])
#                                     +- InMemoryTableScan [restaurant_id#8718, restaurant_city#8719, delivery_status#8721]
#                                           +- InMemoryRelation [order_id#8716, customer_id#8717, restaurant_id#8718, restaurant_city#8719, delivery_city#8720, order_time#8708, pickup_time#8709, delivery_time#8710, delivery_status#8721, delivery_partner_id#8722, order_amount#8723, payment_mode#8724, rating#8725, order_amount_clean#8728, order_amount_valid#8729, order_time_clean#8730, pickup_time_clean#8731, delivery_time_clean#8732, order_time_valid#8733, pickup_time_valid#8734, delivery_time_valid#8735, prep_time_min#8742, delivery_time_gap_min#8743, total_fulfillment_time_min#8738, prep_time_negative#8739, ... 2 more fields], StorageLevel(disk, memory, deserialized, 1 replicas)
#                                                 +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / 60.0) END AS prep_time_min#6970, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / 60.0) END AS delivery_time_gap_min#6971, total_fulfillment_time_min#6966, CASE WHEN isnull(prep_time_min#6964) THEN false ELSE (prep_time_min#6964 < 0.0) END AS prep_time_negative#6967, ... 2 more fields]
#                                                    +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, isnotnull(order_time_clean#6845) AS order_time_valid#6848, isnotnull(pickup_time_clean#6846) AS pickup_time_valid#6849, isnotnull(delivery_time_clean#6847) AS delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / 60.0) END AS prep_time_min#6964, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / 60.0) END AS delivery_time_gap_min#6965, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / 60.0) END AS total_fulfillment_time_min#6966]
#                                                       +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, isnotnull(order_amount_clean#6824) AS order_amount_valid#6825, coalesce(gettimestamp(CASE WHEN isnull(order_time#6624) THEN null WHEN (trim(order_time#6624, None) = ) THEN null WHEN (upper(trim(order_time#6624, None)) = NULL) THEN null ELSE trim(order_time#6624, None) END, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(order_time#6624) THEN null WHEN (trim(order_time#6624, None) = ) THEN null WHEN (upper(trim(order_time#6624, None)) = NULL) THEN null ELSE trim(order_time#6624, None) END, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(order_time#6624) THEN null WHEN (trim(order_time#6624, None) = ) THEN null WHEN (upper(trim(order_time#6624, None)) = NULL) THEN null ELSE trim(order_time#6624, None) END, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS order_time_clean#6845, coalesce(gettimestamp(CASE WHEN isnull(pickup_time#6625) THEN null WHEN (trim(pickup_time#6625, None) = ) THEN null WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN null ELSE trim(pickup_time#6625, None) END, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(pickup_time#6625) THEN null WHEN (trim(pickup_time#6625, None) = ) THEN null WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN null ELSE trim(pickup_time#6625, None) END, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(pickup_time#6625) THEN null WHEN (trim(pickup_time#6625, None) = ) THEN null WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN null ELSE trim(pickup_time#6625, None) END, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS pickup_time_clean#6846, coalesce(gettimestamp(CASE WHEN isnull(delivery_time#6626) THEN null WHEN (trim(delivery_time#6626, None) = ) THEN null WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN null ELSE trim(delivery_time#6626, None) END, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(delivery_time#6626) THEN null WHEN (trim(delivery_time#6626, None) = ) THEN null WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN null ELSE trim(delivery_time#6626, None) END, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(delivery_time#6626) THEN null WHEN (trim(delivery_time#6626, None) = ) THEN null WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN null ELSE trim(delivery_time#6626, None) END, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS delivery_time_clean#6847]
#                                                          +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, CASE WHEN (order_amount_clean#6823 < 0) THEN null ELSE order_amount_clean#6823 END AS order_amount_clean#6824]
#                                                             +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, CASE WHEN RLIKE(order_amount_nocommas#6822, ^\d+$) THEN cast(order_amount_nocommas#6822 as int) END AS order_amount_clean#6823]
#                                                                +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, regexp_replace(order_amount#6818, ,, , 1) AS order_amount_nocommas#6822]
#                                                                   +- *(1) Project [CASE WHEN (isnull(order_id#6619) OR (trim(order_id#6619, None) = )) THEN null ELSE trim(order_id#6619, None) END AS order_id#6811, CASE WHEN (isnull(customer_id#6620) OR (trim(customer_id#6620, None) = )) THEN null ELSE trim(customer_id#6620, None) END AS customer_id#6812, CASE WHEN (isnull(restaurant_id#6621) OR (trim(restaurant_id#6621, None) = )) THEN null ELSE trim(restaurant_id#6621, None) END AS restaurant_id#6813, CASE WHEN (isnull(restaurant_city#6622) OR (trim(restaurant_city#6622, None) = )) THEN null ELSE trim(restaurant_city#6622, None) END AS restaurant_city#6814, CASE WHEN (isnull(delivery_city#6623) OR (trim(delivery_city#6623, None) = )) THEN null ELSE trim(delivery_city#6623, None) END AS delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, CASE WHEN (isnull(delivery_status#6627) OR (trim(delivery_status#6627, None) = )) THEN null ELSE trim(delivery_status#6627, None) END AS delivery_status#6816, CASE WHEN (isnull(delivery_partner_id#6628) OR (trim(delivery_partner_id#6628, None) = )) THEN null ELSE trim(delivery_partner_id#6628, None) END AS delivery_partner_id#6817, CASE WHEN (isnull(order_amount#6629) OR (trim(order_amount#6629, None) = )) THEN null ELSE trim(order_amount#6629, None) END AS order_amount#6818, CASE WHEN (isnull(payment_mode#6630) OR (trim(payment_mode#6630, None) = )) THEN null ELSE trim(payment_mode#6630, None) END AS payment_mode#6819, CASE WHEN (isnull(rating#6631) OR (trim(rating#6631, None) = )) THEN null ELSE trim(rating#6631, None) END AS rating#6820]
#                                                                      +- FileScan csv [order_id#6619,customer_id#6620,restaurant_id#6621,restaurant_city#6622,delivery_city#6623,order_time#6624,pickup_time#6625,delivery_time#6626,delivery_status#6627,delivery_partner_id#6628,order_amount#6629,payment_mode#6630,rating#6631] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/delivery_data.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<order_id:string,customer_id:string,restaurant_id:string,restaurant_city:string,delivery_ci...

# %%
print("City Delay Analysis Query")
avg_gap_per_city_q.explain(True)
# Out:
# City Delay Analysis Query
# == Parsed Logical Plan ==
# 'Aggregate ['delivery_city], ['delivery_city, 'round('avg('delivery_time_gap_min), 2) AS avg_delivery_time_gap_min#8765, 'count(*) AS orders_count#8766]
# +- Filter (isnotnull(delivery_time_gap_min#6971) AND NOT delivery_time_gap_negative#6968)
#    +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6970, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS delivery_time_gap_min#6971, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#       +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS prep_time_min#6970, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#          +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#             +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 1 more fields]
#                +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, CASE WHEN isnull(prep_time_min#6964) THEN false ELSE (prep_time_min#6964 < cast(0 as double)) END AS prep_time_negative#6967]
#                   +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS total_fulfillment_time_min#6966]
#                      +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS delivery_time_gap_min#6965]
#                         +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS prep_time_min#6964]
#                            +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, isnotnull(delivery_time_clean#6847) AS delivery_time_valid#6850]
#                               +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, isnotnull(pickup_time_clean#6846) AS pickup_time_valid#6849]
#                                  +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, isnotnull(order_time_clean#6845) AS order_time_valid#6848]
#                                     +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, coalesce(try_to_timestamp(CASE WHEN isnull(delivery_time#6626) THEN cast(null as string) WHEN (trim(delivery_time#6626, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#6626, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(delivery_time#6626) THEN cast(null as string) WHEN (trim(delivery_time#6626, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#6626, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(delivery_time#6626) THEN cast(null as string) WHEN (trim(delivery_time#6626, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#6626, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS delivery_time_clean#6847]
#                                        +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, coalesce(try_to_timestamp(CASE WHEN isnull(pickup_time#6625) THEN cast(null as string) WHEN (trim(pickup_time#6625, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#6625, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(pickup_time#6625) THEN cast(null as string) WHEN (trim(pickup_time#6625, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#6625, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(pickup_time#6625) THEN cast(null as string) WHEN (trim(pickup_time#6625, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#6625, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS pickup_time_clean#6846]
#                                           +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, coalesce(try_to_timestamp(CASE WHEN isnull(order_time#6624) THEN cast(null as string) WHEN (trim(order_time#6624, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#6624, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#6624, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(order_time#6624) THEN cast(null as string) WHEN (trim(order_time#6624, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#6624, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#6624, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(order_time#6624) THEN cast(null as string) WHEN (trim(order_time#6624, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#6624, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#6624, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS order_time_clean#6845]
#                                              +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825]
#                                                 +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_nocommas#6822, order_amount_clean#6824, isnotnull(order_amount_clean#6824) AS order_amount_valid#6825]
#                                                    +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_nocommas#6822, CASE WHEN (order_amount_clean#6823 < 0) THEN cast(null as int) ELSE order_amount_clean#6823 END AS order_amount_clean#6824]
#                                                       +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_nocommas#6822, CASE WHEN RLIKE(order_amount_nocommas#6822, ^\d+$) THEN cast(order_amount_nocommas#6822 as int) ELSE cast(null as int) END AS order_amount_clean#6823]
#                                                          +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, regexp_replace(order_amount#6818, ,, , 1) AS order_amount_nocommas#6822]
#                                                             +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, CASE WHEN (isnull(rating#6631) OR (trim(rating#6631, None) = )) THEN cast(null as string) ELSE trim(rating#6631, None) END AS rating#6820]
#                                                                +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, CASE WHEN (isnull(payment_mode#6630) OR (trim(payment_mode#6630, None) = )) THEN cast(null as string) ELSE trim(payment_mode#6630, None) END AS payment_mode#6819, rating#6631]
#                                                                   +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, CASE WHEN (isnull(order_amount#6629) OR (trim(order_amount#6629, None) = )) THEN cast(null as string) ELSE trim(order_amount#6629, None) END AS order_amount#6818, payment_mode#6630, rating#6631]
#                                                                      +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, CASE WHEN (isnull(delivery_partner_id#6628) OR (trim(delivery_partner_id#6628, None) = )) THEN cast(null as string) ELSE trim(delivery_partner_id#6628, None) END AS delivery_partner_id#6817, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                         +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, CASE WHEN (isnull(delivery_status#6627) OR (trim(delivery_status#6627, None) = )) THEN cast(null as string) ELSE trim(delivery_status#6627, None) END AS delivery_status#6816, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                            +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, CASE WHEN (isnull(delivery_city#6623) OR (trim(delivery_city#6623, None) = )) THEN cast(null as string) ELSE trim(delivery_city#6623, None) END AS delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                               +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, CASE WHEN (isnull(restaurant_city#6622) OR (trim(restaurant_city#6622, None) = )) THEN cast(null as string) ELSE trim(restaurant_city#6622, None) END AS restaurant_city#6814, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                                  +- Project [order_id#6811, customer_id#6812, CASE WHEN (isnull(restaurant_id#6621) OR (trim(restaurant_id#6621, None) = )) THEN cast(null as string) ELSE trim(restaurant_id#6621, None) END AS restaurant_id#6813, restaurant_city#6622, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                                     +- Project [order_id#6811, CASE WHEN (isnull(customer_id#6620) OR (trim(customer_id#6620, None) = )) THEN cast(null as string) ELSE trim(customer_id#6620, None) END AS customer_id#6812, restaurant_id#6621, restaurant_city#6622, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                                        +- Project [CASE WHEN (isnull(order_id#6619) OR (trim(order_id#6619, None) = )) THEN cast(null as string) ELSE trim(order_id#6619, None) END AS order_id#6811, customer_id#6620, restaurant_id#6621, restaurant_city#6622, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                                           +- Relation [order_id#6619,customer_id#6620,restaurant_id#6621,restaurant_city#6622,delivery_city#6623,order_time#6624,pickup_time#6625,delivery_time#6626,delivery_status#6627,delivery_partner_id#6628,order_amount#6629,payment_mode#6630,rating#6631] csv
#
# == Analyzed Logical Plan ==
# delivery_city: string, avg_delivery_time_gap_min: double, orders_count: bigint
# Aggregate [delivery_city#6815], [delivery_city#6815, round(avg(delivery_time_gap_min#6971), 2) AS avg_delivery_time_gap_min#8765, count(1) AS orders_count#8766L]
# +- Filter (isnotnull(delivery_time_gap_min#6971) AND NOT delivery_time_gap_negative#6968)
#    +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6970, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS delivery_time_gap_min#6971, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#       +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS prep_time_min#6970, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#          +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#             +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 1 more fields]
#                +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, CASE WHEN isnull(prep_time_min#6964) THEN false ELSE (prep_time_min#6964 < cast(0 as double)) END AS prep_time_negative#6967]
#                   +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS total_fulfillment_time_min#6966]
#                      +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS delivery_time_gap_min#6965]
#                         +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS prep_time_min#6964]
#                            +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, isnotnull(delivery_time_clean#6847) AS delivery_time_valid#6850]
#                               +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, isnotnull(pickup_time_clean#6846) AS pickup_time_valid#6849]
#                                  +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, isnotnull(order_time_clean#6845) AS order_time_valid#6848]
#                                     +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, coalesce(try_to_timestamp(CASE WHEN isnull(delivery_time#6626) THEN cast(null as string) WHEN (trim(delivery_time#6626, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#6626, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(delivery_time#6626) THEN cast(null as string) WHEN (trim(delivery_time#6626, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#6626, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(delivery_time#6626) THEN cast(null as string) WHEN (trim(delivery_time#6626, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#6626, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS delivery_time_clean#6847]
#                                        +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, coalesce(try_to_timestamp(CASE WHEN isnull(pickup_time#6625) THEN cast(null as string) WHEN (trim(pickup_time#6625, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#6625, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(pickup_time#6625) THEN cast(null as string) WHEN (trim(pickup_time#6625, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#6625, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(pickup_time#6625) THEN cast(null as string) WHEN (trim(pickup_time#6625, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#6625, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS pickup_time_clean#6846]
#                                           +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, coalesce(try_to_timestamp(CASE WHEN isnull(order_time#6624) THEN cast(null as string) WHEN (trim(order_time#6624, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#6624, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#6624, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(order_time#6624) THEN cast(null as string) WHEN (trim(order_time#6624, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#6624, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#6624, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(order_time#6624) THEN cast(null as string) WHEN (trim(order_time#6624, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#6624, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#6624, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS order_time_clean#6845]
#                                              +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825]
#                                                 +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_nocommas#6822, order_amount_clean#6824, isnotnull(order_amount_clean#6824) AS order_amount_valid#6825]
#                                                    +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_nocommas#6822, CASE WHEN (order_amount_clean#6823 < 0) THEN cast(null as int) ELSE order_amount_clean#6823 END AS order_amount_clean#6824]
#                                                       +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_nocommas#6822, CASE WHEN RLIKE(order_amount_nocommas#6822, ^\d+$) THEN cast(order_amount_nocommas#6822 as int) ELSE cast(null as int) END AS order_amount_clean#6823]
#                                                          +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, regexp_replace(order_amount#6818, ,, , 1) AS order_amount_nocommas#6822]
#                                                             +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, CASE WHEN (isnull(rating#6631) OR (trim(rating#6631, None) = )) THEN cast(null as string) ELSE trim(rating#6631, None) END AS rating#6820]
#                                                                +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, CASE WHEN (isnull(payment_mode#6630) OR (trim(payment_mode#6630, None) = )) THEN cast(null as string) ELSE trim(payment_mode#6630, None) END AS payment_mode#6819, rating#6631]
#                                                                   +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, CASE WHEN (isnull(order_amount#6629) OR (trim(order_amount#6629, None) = )) THEN cast(null as string) ELSE trim(order_amount#6629, None) END AS order_amount#6818, payment_mode#6630, rating#6631]
#                                                                      +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, CASE WHEN (isnull(delivery_partner_id#6628) OR (trim(delivery_partner_id#6628, None) = )) THEN cast(null as string) ELSE trim(delivery_partner_id#6628, None) END AS delivery_partner_id#6817, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                         +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, CASE WHEN (isnull(delivery_status#6627) OR (trim(delivery_status#6627, None) = )) THEN cast(null as string) ELSE trim(delivery_status#6627, None) END AS delivery_status#6816, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                            +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, CASE WHEN (isnull(delivery_city#6623) OR (trim(delivery_city#6623, None) = )) THEN cast(null as string) ELSE trim(delivery_city#6623, None) END AS delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                               +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, CASE WHEN (isnull(restaurant_city#6622) OR (trim(restaurant_city#6622, None) = )) THEN cast(null as string) ELSE trim(restaurant_city#6622, None) END AS restaurant_city#6814, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                                  +- Project [order_id#6811, customer_id#6812, CASE WHEN (isnull(restaurant_id#6621) OR (trim(restaurant_id#6621, None) = )) THEN cast(null as string) ELSE trim(restaurant_id#6621, None) END AS restaurant_id#6813, restaurant_city#6622, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                                     +- Project [order_id#6811, CASE WHEN (isnull(customer_id#6620) OR (trim(customer_id#6620, None) = )) THEN cast(null as string) ELSE trim(customer_id#6620, None) END AS customer_id#6812, restaurant_id#6621, restaurant_city#6622, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                                        +- Project [CASE WHEN (isnull(order_id#6619) OR (trim(order_id#6619, None) = )) THEN cast(null as string) ELSE trim(order_id#6619, None) END AS order_id#6811, customer_id#6620, restaurant_id#6621, restaurant_city#6622, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                                           +- Relation [order_id#6619,customer_id#6620,restaurant_id#6621,restaurant_city#6622,delivery_city#6623,order_time#6624,pickup_time#6625,delivery_time#6626,delivery_status#6627,delivery_partner_id#6628,order_amount#6629,payment_mode#6630,rating#6631] csv
#
# == Optimized Logical Plan ==
# Aggregate [delivery_city#6815], [delivery_city#6815, round(avg(delivery_time_gap_min#6971), 2) AS avg_delivery_time_gap_min#8765, count(1) AS orders_count#8766L]
# +- Project [delivery_city#6815, delivery_time_gap_min#6971]
#    +- Filter (isnotnull(delivery_time_gap_negative#6968) AND (isnotnull(delivery_time_gap_min#6971) AND NOT delivery_time_gap_negative#6968))
#       +- InMemoryRelation [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6970, delivery_time_gap_min#6971, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields], StorageLevel(disk, memory, deserialized, 1 replicas)
#             +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / 60.0) END AS prep_time_min#6970, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / 60.0) END AS delivery_time_gap_min#6971, total_fulfillment_time_min#6966, CASE WHEN isnull(prep_time_min#6964) THEN false ELSE (prep_time_min#6964 < 0.0) END AS prep_time_negative#6967, ... 2 more fields]
#                +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, isnotnull(order_time_clean#6845) AS order_time_valid#6848, isnotnull(pickup_time_clean#6846) AS pickup_time_valid#6849, isnotnull(delivery_time_clean#6847) AS delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / 60.0) END AS prep_time_min#6964, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / 60.0) END AS delivery_time_gap_min#6965, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / 60.0) END AS total_fulfillment_time_min#6966]
#                   +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, isnotnull(order_amount_clean#6824) AS order_amount_valid#6825, coalesce(gettimestamp(CASE WHEN isnull(order_time#6624) THEN null WHEN (trim(order_time#6624, None) = ) THEN null WHEN (upper(trim(order_time#6624, None)) = NULL) THEN null ELSE trim(order_time#6624, None) END, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(order_time#6624) THEN null WHEN (trim(order_time#6624, None) = ) THEN null WHEN (upper(trim(order_time#6624, None)) = NULL) THEN null ELSE trim(order_time#6624, None) END, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(order_time#6624) THEN null WHEN (trim(order_time#6624, None) = ) THEN null WHEN (upper(trim(order_time#6624, None)) = NULL) THEN null ELSE trim(order_time#6624, None) END, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS order_time_clean#6845, coalesce(gettimestamp(CASE WHEN isnull(pickup_time#6625) THEN null WHEN (trim(pickup_time#6625, None) = ) THEN null WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN null ELSE trim(pickup_time#6625, None) END, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(pickup_time#6625) THEN null WHEN (trim(pickup_time#6625, None) = ) THEN null WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN null ELSE trim(pickup_time#6625, None) END, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(pickup_time#6625) THEN null WHEN (trim(pickup_time#6625, None) = ) THEN null WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN null ELSE trim(pickup_time#6625, None) END, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS pickup_time_clean#6846, coalesce(gettimestamp(CASE WHEN isnull(delivery_time#6626) THEN null WHEN (trim(delivery_time#6626, None) = ) THEN null WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN null ELSE trim(delivery_time#6626, None) END, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(delivery_time#6626) THEN null WHEN (trim(delivery_time#6626, None) = ) THEN null WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN null ELSE trim(delivery_time#6626, None) END, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(delivery_time#6626) THEN null WHEN (trim(delivery_time#6626, None) = ) THEN null WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN null ELSE trim(delivery_time#6626, None) END, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS delivery_time_clean#6847]
#                      +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, CASE WHEN (order_amount_clean#6823 < 0) THEN null ELSE order_amount_clean#6823 END AS order_amount_clean#6824]
#                         +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, CASE WHEN RLIKE(order_amount_nocommas#6822, ^\d+$) THEN cast(order_amount_nocommas#6822 as int) END AS order_amount_clean#6823]
#                            +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, regexp_replace(order_amount#6818, ,, , 1) AS order_amount_nocommas#6822]
#                               +- *(1) Project [CASE WHEN (isnull(order_id#6619) OR (trim(order_id#6619, None) = )) THEN null ELSE trim(order_id#6619, None) END AS order_id#6811, CASE WHEN (isnull(customer_id#6620) OR (trim(customer_id#6620, None) = )) THEN null ELSE trim(customer_id#6620, None) END AS customer_id#6812, CASE WHEN (isnull(restaurant_id#6621) OR (trim(restaurant_id#6621, None) = )) THEN null ELSE trim(restaurant_id#6621, None) END AS restaurant_id#6813, CASE WHEN (isnull(restaurant_city#6622) OR (trim(restaurant_city#6622, None) = )) THEN null ELSE trim(restaurant_city#6622, None) END AS restaurant_city#6814, CASE WHEN (isnull(delivery_city#6623) OR (trim(delivery_city#6623, None) = )) THEN null ELSE trim(delivery_city#6623, None) END AS delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, CASE WHEN (isnull(delivery_status#6627) OR (trim(delivery_status#6627, None) = )) THEN null ELSE trim(delivery_status#6627, None) END AS delivery_status#6816, CASE WHEN (isnull(delivery_partner_id#6628) OR (trim(delivery_partner_id#6628, None) = )) THEN null ELSE trim(delivery_partner_id#6628, None) END AS delivery_partner_id#6817, CASE WHEN (isnull(order_amount#6629) OR (trim(order_amount#6629, None) = )) THEN null ELSE trim(order_amount#6629, None) END AS order_amount#6818, CASE WHEN (isnull(payment_mode#6630) OR (trim(payment_mode#6630, None) = )) THEN null ELSE trim(payment_mode#6630, None) END AS payment_mode#6819, CASE WHEN (isnull(rating#6631) OR (trim(rating#6631, None) = )) THEN null ELSE trim(rating#6631, None) END AS rating#6820]
#                                  +- FileScan csv [order_id#6619,customer_id#6620,restaurant_id#6621,restaurant_city#6622,delivery_city#6623,order_time#6624,pickup_time#6625,delivery_time#6626,delivery_status#6627,delivery_partner_id#6628,order_amount#6629,payment_mode#6630,rating#6631] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/delivery_data.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<order_id:string,customer_id:string,restaurant_id:string,restaurant_city:string,delivery_ci...
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[delivery_city#6815], functions=[avg(delivery_time_gap_min#6971), count(1)], output=[delivery_city#6815, avg_delivery_time_gap_min#8765, orders_count#8766L])
#    +- Exchange hashpartitioning(delivery_city#6815, 200), ENSURE_REQUIREMENTS, [plan_id=5937]
#       +- HashAggregate(keys=[delivery_city#6815], functions=[partial_avg(delivery_time_gap_min#6971), partial_count(1)], output=[delivery_city#6815, sum#10036, count#10037L, count#10038L])
#          +- Project [delivery_city#6815, delivery_time_gap_min#6971]
#             +- Filter ((isnotnull(delivery_time_gap_negative#6968) AND isnotnull(delivery_time_gap_min#6971)) AND NOT delivery_time_gap_negative#6968)
#                +- InMemoryTableScan [delivery_city#6815, delivery_time_gap_min#6971, delivery_time_gap_negative#6968], [isnotnull(delivery_time_gap_negative#6968), isnotnull(delivery_time_gap_min#6971), NOT delivery_time_gap_negative#6968]
#                      +- InMemoryRelation [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6970, delivery_time_gap_min#6971, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields], StorageLevel(disk, memory, deserialized, 1 replicas)
#                            +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / 60.0) END AS prep_time_min#6970, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / 60.0) END AS delivery_time_gap_min#6971, total_fulfillment_time_min#6966, CASE WHEN isnull(prep_time_min#6964) THEN false ELSE (prep_time_min#6964 < 0.0) END AS prep_time_negative#6967, ... 2 more fields]
#                               +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, isnotnull(order_time_clean#6845) AS order_time_valid#6848, isnotnull(pickup_time_clean#6846) AS pickup_time_valid#6849, isnotnull(delivery_time_clean#6847) AS delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / 60.0) END AS prep_time_min#6964, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / 60.0) END AS delivery_time_gap_min#6965, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / 60.0) END AS total_fulfillment_time_min#6966]
#                                  +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, isnotnull(order_amount_clean#6824) AS order_amount_valid#6825, coalesce(gettimestamp(CASE WHEN isnull(order_time#6624) THEN null WHEN (trim(order_time#6624, None) = ) THEN null WHEN (upper(trim(order_time#6624, None)) = NULL) THEN null ELSE trim(order_time#6624, None) END, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(order_time#6624) THEN null WHEN (trim(order_time#6624, None) = ) THEN null WHEN (upper(trim(order_time#6624, None)) = NULL) THEN null ELSE trim(order_time#6624, None) END, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(order_time#6624) THEN null WHEN (trim(order_time#6624, None) = ) THEN null WHEN (upper(trim(order_time#6624, None)) = NULL) THEN null ELSE trim(order_time#6624, None) END, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS order_time_clean#6845, coalesce(gettimestamp(CASE WHEN isnull(pickup_time#6625) THEN null WHEN (trim(pickup_time#6625, None) = ) THEN null WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN null ELSE trim(pickup_time#6625, None) END, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(pickup_time#6625) THEN null WHEN (trim(pickup_time#6625, None) = ) THEN null WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN null ELSE trim(pickup_time#6625, None) END, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(pickup_time#6625) THEN null WHEN (trim(pickup_time#6625, None) = ) THEN null WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN null ELSE trim(pickup_time#6625, None) END, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS pickup_time_clean#6846, coalesce(gettimestamp(CASE WHEN isnull(delivery_time#6626) THEN null WHEN (trim(delivery_time#6626, None) = ) THEN null WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN null ELSE trim(delivery_time#6626, None) END, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(delivery_time#6626) THEN null WHEN (trim(delivery_time#6626, None) = ) THEN null WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN null ELSE trim(delivery_time#6626, None) END, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(delivery_time#6626) THEN null WHEN (trim(delivery_time#6626, None) = ) THEN null WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN null ELSE trim(delivery_time#6626, None) END, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS delivery_time_clean#6847]
#                                     +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, CASE WHEN (order_amount_clean#6823 < 0) THEN null ELSE order_amount_clean#6823 END AS order_amount_clean#6824]
#                                        +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, CASE WHEN RLIKE(order_amount_nocommas#6822, ^\d+$) THEN cast(order_amount_nocommas#6822 as int) END AS order_amount_clean#6823]
#                                           +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, regexp_replace(order_amount#6818, ,, , 1) AS order_amount_nocommas#6822]
#                                              +- *(1) Project [CASE WHEN (isnull(order_id#6619) OR (trim(order_id#6619, None) = )) THEN null ELSE trim(order_id#6619, None) END AS order_id#6811, CASE WHEN (isnull(customer_id#6620) OR (trim(customer_id#6620, None) = )) THEN null ELSE trim(customer_id#6620, None) END AS customer_id#6812, CASE WHEN (isnull(restaurant_id#6621) OR (trim(restaurant_id#6621, None) = )) THEN null ELSE trim(restaurant_id#6621, None) END AS restaurant_id#6813, CASE WHEN (isnull(restaurant_city#6622) OR (trim(restaurant_city#6622, None) = )) THEN null ELSE trim(restaurant_city#6622, None) END AS restaurant_city#6814, CASE WHEN (isnull(delivery_city#6623) OR (trim(delivery_city#6623, None) = )) THEN null ELSE trim(delivery_city#6623, None) END AS delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, CASE WHEN (isnull(delivery_status#6627) OR (trim(delivery_status#6627, None) = )) THEN null ELSE trim(delivery_status#6627, None) END AS delivery_status#6816, CASE WHEN (isnull(delivery_partner_id#6628) OR (trim(delivery_partner_id#6628, None) = )) THEN null ELSE trim(delivery_partner_id#6628, None) END AS delivery_partner_id#6817, CASE WHEN (isnull(order_amount#6629) OR (trim(order_amount#6629, None) = )) THEN null ELSE trim(order_amount#6629, None) END AS order_amount#6818, CASE WHEN (isnull(payment_mode#6630) OR (trim(payment_mode#6630, None) = )) THEN null ELSE trim(payment_mode#6630, None) END AS payment_mode#6819, CASE WHEN (isnull(rating#6631) OR (trim(rating#6631, None) = )) THEN null ELSE trim(rating#6631, None) END AS rating#6820]
#                                                 +- FileScan csv [order_id#6619,customer_id#6620,restaurant_id#6621,restaurant_city#6622,delivery_city#6623,order_time#6624,pickup_time#6625,delivery_time#6626,delivery_status#6627,delivery_partner_id#6628,order_amount#6629,payment_mode#6630,rating#6631] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/delivery_data.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<order_id:string,customer_id:string,restaurant_id:string,restaurant_city:string,delivery_ci...

# %%
df_cached.unpersist()
# Out:
# DataFrame[order_id: string, customer_id: string, restaurant_id: string, restaurant_city: string, delivery_city: string, order_time: string, pickup_time: string, delivery_time: string, delivery_status: string, delivery_partner_id: string, order_amount: string, payment_mode: string, rating: string, order_amount_clean: int, order_amount_valid: boolean, order_time_clean: timestamp, pickup_time_clean: timestamp, delivery_time_clean: timestamp, order_time_valid: boolean, pickup_time_valid: boolean, delivery_time_valid: boolean, prep_time_min: double, delivery_time_gap_min: double, total_fulfillment_time_min: double, prep_time_negative: boolean, delivery_time_gap_negative: boolean, total_fulfillment_time_negative: boolean]

# %% [markdown]
# #  Identify shuffle stages

# %% [markdown]
# *   Exchange SinglePartition
# *   SortMergeJoin
# *   Sort
# *   Exchange hashpartitioning
# *   HashAggregate + Exchange
# *   Exchange
# *   Window + Exchange (due to global window ordering)

# %% [markdown]
#  # Repartition by delivery_city.

# %%
df_city = df_cached.repartition("delivery_city").cache()

# %%
restaurant_time_agg_after = (
    df_city.filter(total_valid_filter)
           .groupBy("restaurant_id", "restaurant_city")
           .agg(
               spark_round(avg(col("total_fulfillment_time_min")), 2).alias("avg_total_fulfillment_time_min"),
               count("*").alias("orders_with_valid_time")
           )
)

restaurant_cancel_agg_after = (
    df_city.groupBy("restaurant_id", "restaurant_city")
           .agg(
               count("*").alias("total_orders"),
               spark_sum(when(col("delivery_status") == "CANCELLED", 1).otherwise(0)).alias("cancelled_orders")
           )
           .withColumn("cancellation_rate_pct",
                       spark_round((col("cancelled_orders") / col("total_orders")) * 100.0, 2))
)

restaurants_ranked_after = (
    restaurant_time_agg_after.join(restaurant_cancel_agg_after, ["restaurant_id", "restaurant_city"], "outer")
                             .withColumn("rank_by_avg_fulfillment",
                                         dense_rank().over(Window.orderBy(col("avg_total_fulfillment_time_min").asc())))
                             .withColumn("rank_by_cancellation_rate",
                                         dense_rank().over(Window.orderBy(col("cancellation_rate_pct").asc())))
)

avg_gap_per_city_after = (
    df_city.filter(gap_valid_filter)
           .groupBy("delivery_city")
           .agg(
               spark_round(avg(col("delivery_time_gap_min")), 2).alias("avg_delivery_time_gap_min"),
               count("*").alias("orders_count")
           )
)

# %% [markdown]
# # Compare plans before and after

# %%
print("(Restaurant Ranking) — AFTER")
restaurants_ranked_after.explain(True)
# Out:
# (Restaurant Ranking) — AFTER
# == Parsed Logical Plan ==
# 'Project [unresolvedstarwithcolumns(rank_by_cancellation_rate, 'dense_rank() windowspecdefinition('cancellation_rate_pct ASC NULLS FIRST, unspecifiedframe$()), None)]
# +- Project [restaurant_id#10819, restaurant_city#10820, avg_total_fulfillment_time_min#10714, orders_with_valid_time#10715L, total_orders#10745L, cancelled_orders#10746L, cancellation_rate_pct#10776, rank_by_avg_fulfillment#10821]
#    +- Project [restaurant_id#10819, restaurant_city#10820, avg_total_fulfillment_time_min#10714, orders_with_valid_time#10715L, total_orders#10745L, cancelled_orders#10746L, cancellation_rate_pct#10776, rank_by_avg_fulfillment#10821, rank_by_avg_fulfillment#10821]
#       +- Window [dense_rank(avg_total_fulfillment_time_min#10714) windowspecdefinition(avg_total_fulfillment_time_min#10714 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rank_by_avg_fulfillment#10821], [avg_total_fulfillment_time_min#10714 ASC NULLS FIRST]
#          +- Project [restaurant_id#10819, restaurant_city#10820, avg_total_fulfillment_time_min#10714, orders_with_valid_time#10715L, total_orders#10745L, cancelled_orders#10746L, cancellation_rate_pct#10776]
#             +- Project [coalesce(restaurant_id#6813, restaurant_id#10792) AS restaurant_id#10819, coalesce(restaurant_city#6814, restaurant_city#10793) AS restaurant_city#10820, avg_total_fulfillment_time_min#10714, orders_with_valid_time#10715L, total_orders#10745L, cancelled_orders#10746L, cancellation_rate_pct#10776]
#                +- Join FullOuter, ((restaurant_id#6813 = restaurant_id#10792) AND (restaurant_city#6814 = restaurant_city#10793))
#                   :- Aggregate [restaurant_id#6813, restaurant_city#6814], [restaurant_id#6813, restaurant_city#6814, round(avg(total_fulfillment_time_min#6966), 2) AS avg_total_fulfillment_time_min#10714, count(1) AS orders_with_valid_time#10715L]
#                   :  +- Filter (isnotnull(total_fulfillment_time_min#6966) AND NOT total_fulfillment_time_negative#6969)
#                   :     +- RepartitionByExpression [delivery_city#6815]
#                   :        +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6970, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS delivery_time_gap_min#6971, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#                   :           +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS prep_time_min#6970, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#                   :              +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#                   :                 +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 1 more fields]
#                   :                    +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, CASE WHEN isnull(prep_time_min#6964) THEN false ELSE (prep_time_min#6964 < cast(0 as double)) END AS prep_time_negative#6967]
#                   :                       +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS total_fulfillment_time_min#6966]
#                   :                          +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS delivery_time_gap_min#6965]
#                   :                             +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS prep_time_min#6964]
#                   :                                +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, isnotnull(delivery_time_clean#6847) AS delivery_time_valid#6850]
#                   :                                   +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, isnotnull(pickup_time_clean#6846) AS pickup_time_valid#6849]
#                   :                                      +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, isnotnull(order_time_clean#6845) AS order_time_valid#6848]
#                   :                                         +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, coalesce(try_to_timestamp(CASE WHEN isnull(delivery_time#6626) THEN cast(null as string) WHEN (trim(delivery_time#6626, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#6626, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(delivery_time#6626) THEN cast(null as string) WHEN (trim(delivery_time#6626, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#6626, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(delivery_time#6626) THEN cast(null as string) WHEN (trim(delivery_time#6626, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#6626, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS delivery_time_clean#6847]
#                   :                                            +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, coalesce(try_to_timestamp(CASE WHEN isnull(pickup_time#6625) THEN cast(null as string) WHEN (trim(pickup_time#6625, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#6625, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(pickup_time#6625) THEN cast(null as string) WHEN (trim(pickup_time#6625, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#6625, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(pickup_time#6625) THEN cast(null as string) WHEN (trim(pickup_time#6625, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#6625, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS pickup_time_clean#6846]
#                   :                                               +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, coalesce(try_to_timestamp(CASE WHEN isnull(order_time#6624) THEN cast(null as string) WHEN (trim(order_time#6624, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#6624, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#6624, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(order_time#6624) THEN cast(null as string) WHEN (trim(order_time#6624, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#6624, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#6624, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(order_time#6624) THEN cast(null as string) WHEN (trim(order_time#6624, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#6624, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#6624, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS order_time_clean#6845]
#                   :                                                  +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825]
#                   :                                                     +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_nocommas#6822, order_amount_clean#6824, isnotnull(order_amount_clean#6824) AS order_amount_valid#6825]
#                   :                                                        +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_nocommas#6822, CASE WHEN (order_amount_clean#6823 < 0) THEN cast(null as int) ELSE order_amount_clean#6823 END AS order_amount_clean#6824]
#                   :                                                           +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_nocommas#6822, CASE WHEN RLIKE(order_amount_nocommas#6822, ^\d+$) THEN cast(order_amount_nocommas#6822 as int) ELSE cast(null as int) END AS order_amount_clean#6823]
#                   :                                                              +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, regexp_replace(order_amount#6818, ,, , 1) AS order_amount_nocommas#6822]
#                   :                                                                 +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, CASE WHEN (isnull(rating#6631) OR (trim(rating#6631, None) = )) THEN cast(null as string) ELSE trim(rating#6631, None) END AS rating#6820]
#                   :                                                                    +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, CASE WHEN (isnull(payment_mode#6630) OR (trim(payment_mode#6630, None) = )) THEN cast(null as string) ELSE trim(payment_mode#6630, None) END AS payment_mode#6819, rating#6631]
#                   :                                                                       +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, CASE WHEN (isnull(order_amount#6629) OR (trim(order_amount#6629, None) = )) THEN cast(null as string) ELSE trim(order_amount#6629, None) END AS order_amount#6818, payment_mode#6630, rating#6631]
#                   :                                                                          +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, CASE WHEN (isnull(delivery_partner_id#6628) OR (trim(delivery_partner_id#6628, None) = )) THEN cast(null as string) ELSE trim(delivery_partner_id#6628, None) END AS delivery_partner_id#6817, order_amount#6629, payment_mode#6630, rating#6631]
#                   :                                                                             +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, CASE WHEN (isnull(delivery_status#6627) OR (trim(delivery_status#6627, None) = )) THEN cast(null as string) ELSE trim(delivery_status#6627, None) END AS delivery_status#6816, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                   :                                                                                +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, CASE WHEN (isnull(delivery_city#6623) OR (trim(delivery_city#6623, None) = )) THEN cast(null as string) ELSE trim(delivery_city#6623, None) END AS delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                   :                                                                                   +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, CASE WHEN (isnull(restaurant_city#6622) OR (trim(restaurant_city#6622, None) = )) THEN cast(null as string) ELSE trim(restaurant_city#6622, None) END AS restaurant_city#6814, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                   :                                                                                      +- Project [order_id#6811, customer_id#6812, CASE WHEN (isnull(restaurant_id#6621) OR (trim(restaurant_id#6621, None) = )) THEN cast(null as string) ELSE trim(restaurant_id#6621, None) END AS restaurant_id#6813, restaurant_city#6622, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                   :                                                                                         +- Project [order_id#6811, CASE WHEN (isnull(customer_id#6620) OR (trim(customer_id#6620, None) = )) THEN cast(null as string) ELSE trim(customer_id#6620, None) END AS customer_id#6812, restaurant_id#6621, restaurant_city#6622, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                   :                                                                                            +- Project [CASE WHEN (isnull(order_id#6619) OR (trim(order_id#6619, None) = )) THEN cast(null as string) ELSE trim(order_id#6619, None) END AS order_id#6811, customer_id#6620, restaurant_id#6621, restaurant_city#6622, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                   :                                                                                               +- Relation [order_id#6619,customer_id#6620,restaurant_id#6621,restaurant_city#6622,delivery_city#6623,order_time#6624,pickup_time#6625,delivery_time#6626,delivery_status#6627,delivery_partner_id#6628,order_amount#6629,payment_mode#6630,rating#6631] csv
#                   +- Project [restaurant_id#10792, restaurant_city#10793, total_orders#10745L, cancelled_orders#10746L, round(((cast(cancelled_orders#10746L as double) / cast(total_orders#10745L as double)) * 100.0), 2) AS cancellation_rate_pct#10776]
#                      +- Aggregate [restaurant_id#10792, restaurant_city#10793], [restaurant_id#10792, restaurant_city#10793, count(1) AS total_orders#10745L, sum(CASE WHEN (delivery_status#10795 = CANCELLED) THEN 1 ELSE 0 END) AS cancelled_orders#10746L]
#                         +- RepartitionByExpression [delivery_city#10794]
#                            +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_clean#10802, order_amount_valid#10803, order_time_clean#10804, pickup_time_clean#10805, delivery_time_clean#10806, order_time_valid#10807, pickup_time_valid#10808, delivery_time_valid#10809, prep_time_min#10816, CASE WHEN (isnotnull(delivery_time_clean#10806) AND isnotnull(pickup_time_clean#10805)) THEN (cast((cast(delivery_time_clean#10806 as bigint) - cast(pickup_time_clean#10805 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS delivery_time_gap_min#10817, total_fulfillment_time_min#10812, prep_time_negative#10813, ... 2 more fields]
#                               +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_clean#10802, order_amount_valid#10803, order_time_clean#10804, pickup_time_clean#10805, delivery_time_clean#10806, order_time_valid#10807, pickup_time_valid#10808, delivery_time_valid#10809, CASE WHEN (isnotnull(pickup_time_clean#10805) AND isnotnull(order_time_clean#10804)) THEN (cast((cast(pickup_time_clean#10805 as bigint) - cast(order_time_clean#10804 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS prep_time_min#10816, delivery_time_gap_min#10811, total_fulfillment_time_min#10812, prep_time_negative#10813, ... 2 more fields]
#                                  +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_clean#10802, order_amount_valid#10803, order_time_clean#10804, pickup_time_clean#10805, delivery_time_clean#10806, order_time_valid#10807, pickup_time_valid#10808, delivery_time_valid#10809, prep_time_min#10810, delivery_time_gap_min#10811, total_fulfillment_time_min#10812, prep_time_negative#10813, ... 2 more fields]
#                                     +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_clean#10802, order_amount_valid#10803, order_time_clean#10804, pickup_time_clean#10805, delivery_time_clean#10806, order_time_valid#10807, pickup_time_valid#10808, delivery_time_valid#10809, prep_time_min#10810, delivery_time_gap_min#10811, total_fulfillment_time_min#10812, prep_time_negative#10813, ... 1 more fields]
#                                        +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_clean#10802, order_amount_valid#10803, order_time_clean#10804, pickup_time_clean#10805, delivery_time_clean#10806, order_time_valid#10807, pickup_time_valid#10808, delivery_time_valid#10809, prep_time_min#10810, delivery_time_gap_min#10811, total_fulfillment_time_min#10812, CASE WHEN isnull(prep_time_min#10810) THEN false ELSE (prep_time_min#10810 < cast(0 as double)) END AS prep_time_negative#10813]
#                                           +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_clean#10802, order_amount_valid#10803, order_time_clean#10804, pickup_time_clean#10805, delivery_time_clean#10806, order_time_valid#10807, pickup_time_valid#10808, delivery_time_valid#10809, prep_time_min#10810, delivery_time_gap_min#10811, CASE WHEN (isnotnull(delivery_time_clean#10806) AND isnotnull(order_time_clean#10804)) THEN (cast((cast(delivery_time_clean#10806 as bigint) - cast(order_time_clean#10804 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS total_fulfillment_time_min#10812]
#                                              +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_clean#10802, order_amount_valid#10803, order_time_clean#10804, pickup_time_clean#10805, delivery_time_clean#10806, order_time_valid#10807, pickup_time_valid#10808, delivery_time_valid#10809, prep_time_min#10810, CASE WHEN (isnotnull(delivery_time_clean#10806) AND isnotnull(pickup_time_clean#10805)) THEN (cast((cast(delivery_time_clean#10806 as bigint) - cast(pickup_time_clean#10805 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS delivery_time_gap_min#10811]
#                                                 +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_clean#10802, order_amount_valid#10803, order_time_clean#10804, pickup_time_clean#10805, delivery_time_clean#10806, order_time_valid#10807, pickup_time_valid#10808, delivery_time_valid#10809, CASE WHEN (isnotnull(pickup_time_clean#10805) AND isnotnull(order_time_clean#10804)) THEN (cast((cast(pickup_time_clean#10805 as bigint) - cast(order_time_clean#10804 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS prep_time_min#10810]
#                                                    +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_clean#10802, order_amount_valid#10803, order_time_clean#10804, pickup_time_clean#10805, delivery_time_clean#10806, order_time_valid#10807, pickup_time_valid#10808, isnotnull(delivery_time_clean#10806) AS delivery_time_valid#10809]
#                                                       +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_clean#10802, order_amount_valid#10803, order_time_clean#10804, pickup_time_clean#10805, delivery_time_clean#10806, order_time_valid#10807, isnotnull(pickup_time_clean#10805) AS pickup_time_valid#10808]
#                                                          +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_clean#10802, order_amount_valid#10803, order_time_clean#10804, pickup_time_clean#10805, delivery_time_clean#10806, isnotnull(order_time_clean#10804) AS order_time_valid#10807]
#                                                             +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_clean#10802, order_amount_valid#10803, order_time_clean#10804, pickup_time_clean#10805, coalesce(try_to_timestamp(CASE WHEN isnull(delivery_time#10784) THEN cast(null as string) WHEN (trim(delivery_time#10784, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#10784, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#10784, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(delivery_time#10784) THEN cast(null as string) WHEN (trim(delivery_time#10784, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#10784, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#10784, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(delivery_time#10784) THEN cast(null as string) WHEN (trim(delivery_time#10784, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#10784, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#10784, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS delivery_time_clean#10806]
#                                                                +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_clean#10802, order_amount_valid#10803, order_time_clean#10804, coalesce(try_to_timestamp(CASE WHEN isnull(pickup_time#10783) THEN cast(null as string) WHEN (trim(pickup_time#10783, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#10783, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#10783, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(pickup_time#10783) THEN cast(null as string) WHEN (trim(pickup_time#10783, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#10783, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#10783, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(pickup_time#10783) THEN cast(null as string) WHEN (trim(pickup_time#10783, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#10783, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#10783, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS pickup_time_clean#10805]
#                                                                   +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_clean#10802, order_amount_valid#10803, coalesce(try_to_timestamp(CASE WHEN isnull(order_time#10782) THEN cast(null as string) WHEN (trim(order_time#10782, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#10782, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#10782, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(order_time#10782) THEN cast(null as string) WHEN (trim(order_time#10782, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#10782, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#10782, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(order_time#10782) THEN cast(null as string) WHEN (trim(order_time#10782, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#10782, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#10782, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS order_time_clean#10804]
#                                                                      +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_clean#10802, order_amount_valid#10803]
#                                                                         +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_nocommas#10800, order_amount_clean#10802, isnotnull(order_amount_clean#10802) AS order_amount_valid#10803]
#                                                                            +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_nocommas#10800, CASE WHEN (order_amount_clean#10801 < 0) THEN cast(null as int) ELSE order_amount_clean#10801 END AS order_amount_clean#10802]
#                                                                               +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_nocommas#10800, CASE WHEN RLIKE(order_amount_nocommas#10800, ^\d+$) THEN cast(order_amount_nocommas#10800 as int) ELSE cast(null as int) END AS order_amount_clean#10801]
#                                                                                  +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, regexp_replace(order_amount#10797, ,, , 1) AS order_amount_nocommas#10800]
#                                                                                     +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, CASE WHEN (isnull(rating#10789) OR (trim(rating#10789, None) = )) THEN cast(null as string) ELSE trim(rating#10789, None) END AS rating#10799]
#                                                                                        +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, CASE WHEN (isnull(payment_mode#10788) OR (trim(payment_mode#10788, None) = )) THEN cast(null as string) ELSE trim(payment_mode#10788, None) END AS payment_mode#10798, rating#10789]
#                                                                                           +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, CASE WHEN (isnull(order_amount#10787) OR (trim(order_amount#10787, None) = )) THEN cast(null as string) ELSE trim(order_amount#10787, None) END AS order_amount#10797, payment_mode#10788, rating#10789]
#                                                                                              +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, CASE WHEN (isnull(delivery_partner_id#10786) OR (trim(delivery_partner_id#10786, None) = )) THEN cast(null as string) ELSE trim(delivery_partner_id#10786, None) END AS delivery_partner_id#10796, order_amount#10787, payment_mode#10788, rating#10789]
#                                                                                                 +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, CASE WHEN (isnull(delivery_status#10785) OR (trim(delivery_status#10785, None) = )) THEN cast(null as string) ELSE trim(delivery_status#10785, None) END AS delivery_status#10795, delivery_partner_id#10786, order_amount#10787, payment_mode#10788, rating#10789]
#                                                                                                    +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, CASE WHEN (isnull(delivery_city#10781) OR (trim(delivery_city#10781, None) = )) THEN cast(null as string) ELSE trim(delivery_city#10781, None) END AS delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10785, delivery_partner_id#10786, order_amount#10787, payment_mode#10788, rating#10789]
#                                                                                                       +- Project [order_id#10790, customer_id#10791, restaurant_id#10792, CASE WHEN (isnull(restaurant_city#10780) OR (trim(restaurant_city#10780, None) = )) THEN cast(null as string) ELSE trim(restaurant_city#10780, None) END AS restaurant_city#10793, delivery_city#10781, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10785, delivery_partner_id#10786, order_amount#10787, payment_mode#10788, rating#10789]
#                                                                                                          +- Project [order_id#10790, customer_id#10791, CASE WHEN (isnull(restaurant_id#10779) OR (trim(restaurant_id#10779, None) = )) THEN cast(null as string) ELSE trim(restaurant_id#10779, None) END AS restaurant_id#10792, restaurant_city#10780, delivery_city#10781, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10785, delivery_partner_id#10786, order_amount#10787, payment_mode#10788, rating#10789]
#                                                                                                             +- Project [order_id#10790, CASE WHEN (isnull(customer_id#10778) OR (trim(customer_id#10778, None) = )) THEN cast(null as string) ELSE trim(customer_id#10778, None) END AS customer_id#10791, restaurant_id#10779, restaurant_city#10780, delivery_city#10781, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10785, delivery_partner_id#10786, order_amount#10787, payment_mode#10788, rating#10789]
#                                                                                                                +- Project [CASE WHEN (isnull(order_id#10777) OR (trim(order_id#10777, None) = )) THEN cast(null as string) ELSE trim(order_id#10777, None) END AS order_id#10790, customer_id#10778, restaurant_id#10779, restaurant_city#10780, delivery_city#10781, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10785, delivery_partner_id#10786, order_amount#10787, payment_mode#10788, rating#10789]
#                                                                                                                   +- Relation [order_id#10777,customer_id#10778,restaurant_id#10779,restaurant_city#10780,delivery_city#10781,order_time#10782,pickup_time#10783,delivery_time#10784,delivery_status#10785,delivery_partner_id#10786,order_amount#10787,payment_mode#10788,rating#10789] csv
#
# == Analyzed Logical Plan ==
# restaurant_id: string, restaurant_city: string, avg_total_fulfillment_time_min: double, orders_with_valid_time: bigint, total_orders: bigint, cancelled_orders: bigint, cancellation_rate_pct: double, rank_by_avg_fulfillment: int, rank_by_cancellation_rate: int
# Project [restaurant_id#10819, restaurant_city#10820, avg_total_fulfillment_time_min#10714, orders_with_valid_time#10715L, total_orders#10745L, cancelled_orders#10746L, cancellation_rate_pct#10776, rank_by_avg_fulfillment#10821, rank_by_cancellation_rate#10830]
# +- Project [restaurant_id#10819, restaurant_city#10820, avg_total_fulfillment_time_min#10714, orders_with_valid_time#10715L, total_orders#10745L, cancelled_orders#10746L, cancellation_rate_pct#10776, rank_by_avg_fulfillment#10821, rank_by_cancellation_rate#10830, rank_by_cancellation_rate#10830]
#    +- Window [dense_rank(cancellation_rate_pct#10776) windowspecdefinition(cancellation_rate_pct#10776 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rank_by_cancellation_rate#10830], [cancellation_rate_pct#10776 ASC NULLS FIRST]
#       +- Project [restaurant_id#10819, restaurant_city#10820, avg_total_fulfillment_time_min#10714, orders_with_valid_time#10715L, total_orders#10745L, cancelled_orders#10746L, cancellation_rate_pct#10776, rank_by_avg_fulfillment#10821]
#          +- Project [restaurant_id#10819, restaurant_city#10820, avg_total_fulfillment_time_min#10714, orders_with_valid_time#10715L, total_orders#10745L, cancelled_orders#10746L, cancellation_rate_pct#10776, rank_by_avg_fulfillment#10821]
#             +- Project [restaurant_id#10819, restaurant_city#10820, avg_total_fulfillment_time_min#10714, orders_with_valid_time#10715L, total_orders#10745L, cancelled_orders#10746L, cancellation_rate_pct#10776, rank_by_avg_fulfillment#10821, rank_by_avg_fulfillment#10821]
#                +- Window [dense_rank(avg_total_fulfillment_time_min#10714) windowspecdefinition(avg_total_fulfillment_time_min#10714 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rank_by_avg_fulfillment#10821], [avg_total_fulfillment_time_min#10714 ASC NULLS FIRST]
#                   +- Project [restaurant_id#10819, restaurant_city#10820, avg_total_fulfillment_time_min#10714, orders_with_valid_time#10715L, total_orders#10745L, cancelled_orders#10746L, cancellation_rate_pct#10776]
#                      +- Project [coalesce(restaurant_id#6813, restaurant_id#10792) AS restaurant_id#10819, coalesce(restaurant_city#6814, restaurant_city#10793) AS restaurant_city#10820, avg_total_fulfillment_time_min#10714, orders_with_valid_time#10715L, total_orders#10745L, cancelled_orders#10746L, cancellation_rate_pct#10776]
#                         +- Join FullOuter, ((restaurant_id#6813 = restaurant_id#10792) AND (restaurant_city#6814 = restaurant_city#10793))
#                            :- Aggregate [restaurant_id#6813, restaurant_city#6814], [restaurant_id#6813, restaurant_city#6814, round(avg(total_fulfillment_time_min#6966), 2) AS avg_total_fulfillment_time_min#10714, count(1) AS orders_with_valid_time#10715L]
#                            :  +- Filter (isnotnull(total_fulfillment_time_min#6966) AND NOT total_fulfillment_time_negative#6969)
#                            :     +- RepartitionByExpression [delivery_city#6815]
#                            :        +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6970, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS delivery_time_gap_min#6971, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#                            :           +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS prep_time_min#6970, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#                            :              +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
# ...
#                      :                                                           +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, CASE WHEN RLIKE(order_amount_nocommas#6822, ^\d+$) THEN cast(order_amount_nocommas#6822 as int) END AS order_amount_clean#6823]
#                      :                                                              +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, regexp_replace(order_amount#6818, ,, , 1) AS order_amount_nocommas#6822]
#                      :                                                                 +- *(1) Project [CASE WHEN (isnull(order_id#6619) OR (trim(order_id#6619, None) = )) THEN null ELSE trim(order_id#6619, None) END AS order_id#6811, CASE WHEN (isnull(customer_id#6620) OR (trim(customer_id#6620, None) = )) THEN null ELSE trim(customer_id#6620, None) END AS customer_id#6812, CASE WHEN (isnull(restaurant_id#6621) OR (trim(restaurant_id#6621, None) = )) THEN null ELSE trim(restaurant_id#6621, None) END AS restaurant_id#6813, CASE WHEN (isnull(restaurant_city#6622) OR (trim(restaurant_city#6622, None) = )) THEN null ELSE trim(restaurant_city#6622, None) END AS restaurant_city#6814, CASE WHEN (isnull(delivery_city#6623) OR (trim(delivery_city#6623, None) = )) THEN null ELSE trim(delivery_city#6623, None) END AS delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, CASE WHEN (isnull(delivery_status#6627) OR (trim(delivery_status#6627, None) = )) THEN null ELSE trim(delivery_status#6627, None) END AS delivery_status#6816, CASE WHEN (isnull(delivery_partner_id#6628) OR (trim(delivery_partner_id#6628, None) = )) THEN null ELSE trim(delivery_partner_id#6628, None) END AS delivery_partner_id#6817, CASE WHEN (isnull(order_amount#6629) OR (trim(order_amount#6629, None) = )) THEN null ELSE trim(order_amount#6629, None) END AS order_amount#6818, CASE WHEN (isnull(payment_mode#6630) OR (trim(payment_mode#6630, None) = )) THEN null ELSE trim(payment_mode#6630, None) END AS payment_mode#6819, CASE WHEN (isnull(rating#6631) OR (trim(rating#6631, None) = )) THEN null ELSE trim(rating#6631, None) END AS rating#6820]
#                      :                                                                    +- FileScan csv [order_id#6619,customer_id#6620,restaurant_id#6621,restaurant_city#6622,delivery_city#6623,order_time#6624,pickup_time#6625,delivery_time#6626,delivery_status#6627,delivery_partner_id#6628,order_amount#6629,payment_mode#6630,rating#6631] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/delivery_data.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<order_id:string,customer_id:string,restaurant_id:string,restaurant_city:string,delivery_ci...
#                      +- Sort [restaurant_id#10792 ASC NULLS FIRST, restaurant_city#10793 ASC NULLS FIRST], false, 0
#                         +- Project [restaurant_id#10792, restaurant_city#10793, total_orders#10745L, cancelled_orders#10746L, round(((cast(cancelled_orders#10746L as double) / cast(total_orders#10745L as double)) * 100.0), 2) AS cancellation_rate_pct#10776]
#                            +- HashAggregate(keys=[restaurant_id#10792, restaurant_city#10793], functions=[count(1), sum(CASE WHEN (delivery_status#10795 = CANCELLED) THEN 1 ELSE 0 END)], output=[restaurant_id#10792, restaurant_city#10793, total_orders#10745L, cancelled_orders#10746L])
#                               +- Exchange hashpartitioning(restaurant_id#10792, restaurant_city#10793, 200), ENSURE_REQUIREMENTS, [plan_id=6033]
#                                  +- HashAggregate(keys=[restaurant_id#10792, restaurant_city#10793], functions=[partial_count(1), partial_sum(CASE WHEN (delivery_status#10795 = CANCELLED) THEN 1 ELSE 0 END)], output=[restaurant_id#10792, restaurant_city#10793, count#11700L, sum#11701L])
#                                     +- InMemoryTableScan [restaurant_id#10792, restaurant_city#10793, delivery_status#10795]
#                                           +- InMemoryRelation [order_id#10790, customer_id#10791, restaurant_id#10792, restaurant_city#10793, delivery_city#10794, order_time#10782, pickup_time#10783, delivery_time#10784, delivery_status#10795, delivery_partner_id#10796, order_amount#10797, payment_mode#10798, rating#10799, order_amount_clean#10802, order_amount_valid#10803, order_time_clean#10804, pickup_time_clean#10805, delivery_time_clean#10806, order_time_valid#10807, pickup_time_valid#10808, delivery_time_valid#10809, prep_time_min#10816, delivery_time_gap_min#10817, total_fulfillment_time_min#10812, prep_time_negative#10813, ... 2 more fields], StorageLevel(disk, memory, deserialized, 1 replicas)
#                                                 +- AdaptiveSparkPlan isFinalPlan=false
#                                                    +- Exchange hashpartitioning(delivery_city#6815, 200), REPARTITION_BY_COL, [plan_id=5983]
#                                                       +- InMemoryTableScan [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6970, delivery_time_gap_min#6971, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#                                                             +- InMemoryRelation [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6970, delivery_time_gap_min#6971, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields], StorageLevel(disk, memory, deserialized, 1 replicas)
#                                                                   +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / 60.0) END AS prep_time_min#6970, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / 60.0) END AS delivery_time_gap_min#6971, total_fulfillment_time_min#6966, CASE WHEN isnull(prep_time_min#6964) THEN false ELSE (prep_time_min#6964 < 0.0) END AS prep_time_negative#6967, ... 2 more fields]
#                                                                      +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, isnotnull(order_time_clean#6845) AS order_time_valid#6848, isnotnull(pickup_time_clean#6846) AS pickup_time_valid#6849, isnotnull(delivery_time_clean#6847) AS delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / 60.0) END AS prep_time_min#6964, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / 60.0) END AS delivery_time_gap_min#6965, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / 60.0) END AS total_fulfillment_time_min#6966]
#                                                                         +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, isnotnull(order_amount_clean#6824) AS order_amount_valid#6825, coalesce(gettimestamp(CASE WHEN isnull(order_time#6624) THEN null WHEN (trim(order_time#6624, None) = ) THEN null WHEN (upper(trim(order_time#6624, None)) = NULL) THEN null ELSE trim(order_time#6624, None) END, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(order_time#6624) THEN null WHEN (trim(order_time#6624, None) = ) THEN null WHEN (upper(trim(order_time#6624, None)) = NULL) THEN null ELSE trim(order_time#6624, None) END, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(order_time#6624) THEN null WHEN (trim(order_time#6624, None) = ) THEN null WHEN (upper(trim(order_time#6624, None)) = NULL) THEN null ELSE trim(order_time#6624, None) END, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS order_time_clean#6845, coalesce(gettimestamp(CASE WHEN isnull(pickup_time#6625) THEN null WHEN (trim(pickup_time#6625, None) = ) THEN null WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN null ELSE trim(pickup_time#6625, None) END, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(pickup_time#6625) THEN null WHEN (trim(pickup_time#6625, None) = ) THEN null WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN null ELSE trim(pickup_time#6625, None) END, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(pickup_time#6625) THEN null WHEN (trim(pickup_time#6625, None) = ) THEN null WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN null ELSE trim(pickup_time#6625, None) END, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS pickup_time_clean#6846, coalesce(gettimestamp(CASE WHEN isnull(delivery_time#6626) THEN null WHEN (trim(delivery_time#6626, None) = ) THEN null WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN null ELSE trim(delivery_time#6626, None) END, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(delivery_time#6626) THEN null WHEN (trim(delivery_time#6626, None) = ) THEN null WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN null ELSE trim(delivery_time#6626, None) END, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(delivery_time#6626) THEN null WHEN (trim(delivery_time#6626, None) = ) THEN null WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN null ELSE trim(delivery_time#6626, None) END, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS delivery_time_clean#6847]
#                                                                            +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, CASE WHEN (order_amount_clean#6823 < 0) THEN null ELSE order_amount_clean#6823 END AS order_amount_clean#6824]
#                                                                               +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, CASE WHEN RLIKE(order_amount_nocommas#6822, ^\d+$) THEN cast(order_amount_nocommas#6822 as int) END AS order_amount_clean#6823]
#                                                                                  +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, regexp_replace(order_amount#6818, ,, , 1) AS order_amount_nocommas#6822]
#                                                                                     +- *(1) Project [CASE WHEN (isnull(order_id#6619) OR (trim(order_id#6619, None) = )) THEN null ELSE trim(order_id#6619, None) END AS order_id#6811, CASE WHEN (isnull(customer_id#6620) OR (trim(customer_id#6620, None) = )) THEN null ELSE trim(customer_id#6620, None) END AS customer_id#6812, CASE WHEN (isnull(restaurant_id#6621) OR (trim(restaurant_id#6621, None) = )) THEN null ELSE trim(restaurant_id#6621, None) END AS restaurant_id#6813, CASE WHEN (isnull(restaurant_city#6622) OR (trim(restaurant_city#6622, None) = )) THEN null ELSE trim(restaurant_city#6622, None) END AS restaurant_city#6814, CASE WHEN (isnull(delivery_city#6623) OR (trim(delivery_city#6623, None) = )) THEN null ELSE trim(delivery_city#6623, None) END AS delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, CASE WHEN (isnull(delivery_status#6627) OR (trim(delivery_status#6627, None) = )) THEN null ELSE trim(delivery_status#6627, None) END AS delivery_status#6816, CASE WHEN (isnull(delivery_partner_id#6628) OR (trim(delivery_partner_id#6628, None) = )) THEN null ELSE trim(delivery_partner_id#6628, None) END AS delivery_partner_id#6817, CASE WHEN (isnull(order_amount#6629) OR (trim(order_amount#6629, None) = )) THEN null ELSE trim(order_amount#6629, None) END AS order_amount#6818, CASE WHEN (isnull(payment_mode#6630) OR (trim(payment_mode#6630, None) = )) THEN null ELSE trim(payment_mode#6630, None) END AS payment_mode#6819, CASE WHEN (isnull(rating#6631) OR (trim(rating#6631, None) = )) THEN null ELSE trim(rating#6631, None) END AS rating#6820]
#                                                                                        +- FileScan csv [order_id#6619,customer_id#6620,restaurant_id#6621,restaurant_city#6622,delivery_city#6623,order_time#6624,pickup_time#6625,delivery_time#6626,delivery_status#6627,delivery_partner_id#6628,order_amount#6629,payment_mode#6630,rating#6631] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/delivery_data.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<order_id:string,customer_id:string,restaurant_id:string,restaurant_city:string,delivery_ci...

# %%
print("EXPLAIN (City Delay) — AFTER")
avg_gap_per_city_after.explain(True)
# Out:
# EXPLAIN (City Delay) — AFTER
# == Parsed Logical Plan ==
# 'Aggregate ['delivery_city], ['delivery_city, 'round('avg('delivery_time_gap_min), 2) AS avg_delivery_time_gap_min#10839, 'count(*) AS orders_count#10840]
# +- Filter (isnotnull(delivery_time_gap_min#6971) AND NOT delivery_time_gap_negative#6968)
#    +- RepartitionByExpression [delivery_city#6815]
#       +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6970, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS delivery_time_gap_min#6971, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#          +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS prep_time_min#6970, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#             +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#                +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 1 more fields]
#                   +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, CASE WHEN isnull(prep_time_min#6964) THEN false ELSE (prep_time_min#6964 < cast(0 as double)) END AS prep_time_negative#6967]
#                      +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS total_fulfillment_time_min#6966]
#                         +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS delivery_time_gap_min#6965]
#                            +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS prep_time_min#6964]
#                               +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, isnotnull(delivery_time_clean#6847) AS delivery_time_valid#6850]
#                                  +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, isnotnull(pickup_time_clean#6846) AS pickup_time_valid#6849]
#                                     +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, isnotnull(order_time_clean#6845) AS order_time_valid#6848]
#                                        +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, coalesce(try_to_timestamp(CASE WHEN isnull(delivery_time#6626) THEN cast(null as string) WHEN (trim(delivery_time#6626, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#6626, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(delivery_time#6626) THEN cast(null as string) WHEN (trim(delivery_time#6626, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#6626, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(delivery_time#6626) THEN cast(null as string) WHEN (trim(delivery_time#6626, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#6626, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS delivery_time_clean#6847]
#                                           +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, coalesce(try_to_timestamp(CASE WHEN isnull(pickup_time#6625) THEN cast(null as string) WHEN (trim(pickup_time#6625, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#6625, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(pickup_time#6625) THEN cast(null as string) WHEN (trim(pickup_time#6625, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#6625, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(pickup_time#6625) THEN cast(null as string) WHEN (trim(pickup_time#6625, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#6625, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS pickup_time_clean#6846]
#                                              +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, coalesce(try_to_timestamp(CASE WHEN isnull(order_time#6624) THEN cast(null as string) WHEN (trim(order_time#6624, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#6624, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#6624, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(order_time#6624) THEN cast(null as string) WHEN (trim(order_time#6624, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#6624, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#6624, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(order_time#6624) THEN cast(null as string) WHEN (trim(order_time#6624, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#6624, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#6624, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS order_time_clean#6845]
#                                                 +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825]
#                                                    +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_nocommas#6822, order_amount_clean#6824, isnotnull(order_amount_clean#6824) AS order_amount_valid#6825]
#                                                       +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_nocommas#6822, CASE WHEN (order_amount_clean#6823 < 0) THEN cast(null as int) ELSE order_amount_clean#6823 END AS order_amount_clean#6824]
#                                                          +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_nocommas#6822, CASE WHEN RLIKE(order_amount_nocommas#6822, ^\d+$) THEN cast(order_amount_nocommas#6822 as int) ELSE cast(null as int) END AS order_amount_clean#6823]
#                                                             +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, regexp_replace(order_amount#6818, ,, , 1) AS order_amount_nocommas#6822]
#                                                                +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, CASE WHEN (isnull(rating#6631) OR (trim(rating#6631, None) = )) THEN cast(null as string) ELSE trim(rating#6631, None) END AS rating#6820]
#                                                                   +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, CASE WHEN (isnull(payment_mode#6630) OR (trim(payment_mode#6630, None) = )) THEN cast(null as string) ELSE trim(payment_mode#6630, None) END AS payment_mode#6819, rating#6631]
#                                                                      +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, CASE WHEN (isnull(order_amount#6629) OR (trim(order_amount#6629, None) = )) THEN cast(null as string) ELSE trim(order_amount#6629, None) END AS order_amount#6818, payment_mode#6630, rating#6631]
#                                                                         +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, CASE WHEN (isnull(delivery_partner_id#6628) OR (trim(delivery_partner_id#6628, None) = )) THEN cast(null as string) ELSE trim(delivery_partner_id#6628, None) END AS delivery_partner_id#6817, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                            +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, CASE WHEN (isnull(delivery_status#6627) OR (trim(delivery_status#6627, None) = )) THEN cast(null as string) ELSE trim(delivery_status#6627, None) END AS delivery_status#6816, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                               +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, CASE WHEN (isnull(delivery_city#6623) OR (trim(delivery_city#6623, None) = )) THEN cast(null as string) ELSE trim(delivery_city#6623, None) END AS delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                                  +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, CASE WHEN (isnull(restaurant_city#6622) OR (trim(restaurant_city#6622, None) = )) THEN cast(null as string) ELSE trim(restaurant_city#6622, None) END AS restaurant_city#6814, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                                     +- Project [order_id#6811, customer_id#6812, CASE WHEN (isnull(restaurant_id#6621) OR (trim(restaurant_id#6621, None) = )) THEN cast(null as string) ELSE trim(restaurant_id#6621, None) END AS restaurant_id#6813, restaurant_city#6622, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                                        +- Project [order_id#6811, CASE WHEN (isnull(customer_id#6620) OR (trim(customer_id#6620, None) = )) THEN cast(null as string) ELSE trim(customer_id#6620, None) END AS customer_id#6812, restaurant_id#6621, restaurant_city#6622, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                                           +- Project [CASE WHEN (isnull(order_id#6619) OR (trim(order_id#6619, None) = )) THEN cast(null as string) ELSE trim(order_id#6619, None) END AS order_id#6811, customer_id#6620, restaurant_id#6621, restaurant_city#6622, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                                              +- Relation [order_id#6619,customer_id#6620,restaurant_id#6621,restaurant_city#6622,delivery_city#6623,order_time#6624,pickup_time#6625,delivery_time#6626,delivery_status#6627,delivery_partner_id#6628,order_amount#6629,payment_mode#6630,rating#6631] csv
#
# == Analyzed Logical Plan ==
# delivery_city: string, avg_delivery_time_gap_min: double, orders_count: bigint
# Aggregate [delivery_city#6815], [delivery_city#6815, round(avg(delivery_time_gap_min#6971), 2) AS avg_delivery_time_gap_min#10839, count(1) AS orders_count#10840L]
# +- Filter (isnotnull(delivery_time_gap_min#6971) AND NOT delivery_time_gap_negative#6968)
#    +- RepartitionByExpression [delivery_city#6815]
#       +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6970, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS delivery_time_gap_min#6971, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#          +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS prep_time_min#6970, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#             +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#                +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 1 more fields]
#                   +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, total_fulfillment_time_min#6966, CASE WHEN isnull(prep_time_min#6964) THEN false ELSE (prep_time_min#6964 < cast(0 as double)) END AS prep_time_negative#6967]
#                      +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, delivery_time_gap_min#6965, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS total_fulfillment_time_min#6966]
#                         +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6964, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS delivery_time_gap_min#6965]
#                            +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / cast(60.0 as double)) ELSE cast(null as double) END AS prep_time_min#6964]
#                               +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, isnotnull(delivery_time_clean#6847) AS delivery_time_valid#6850]
#                                  +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, isnotnull(pickup_time_clean#6846) AS pickup_time_valid#6849]
#                                     +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, isnotnull(order_time_clean#6845) AS order_time_valid#6848]
#                                        +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, coalesce(try_to_timestamp(CASE WHEN isnull(delivery_time#6626) THEN cast(null as string) WHEN (trim(delivery_time#6626, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#6626, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(delivery_time#6626) THEN cast(null as string) WHEN (trim(delivery_time#6626, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#6626, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(delivery_time#6626) THEN cast(null as string) WHEN (trim(delivery_time#6626, None) = ) THEN cast(null as string) WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN cast(null as string) ELSE trim(delivery_time#6626, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS delivery_time_clean#6847]
#                                           +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, coalesce(try_to_timestamp(CASE WHEN isnull(pickup_time#6625) THEN cast(null as string) WHEN (trim(pickup_time#6625, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#6625, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(pickup_time#6625) THEN cast(null as string) WHEN (trim(pickup_time#6625, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#6625, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(pickup_time#6625) THEN cast(null as string) WHEN (trim(pickup_time#6625, None) = ) THEN cast(null as string) WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN cast(null as string) ELSE trim(pickup_time#6625, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS pickup_time_clean#6846]
#                                              +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, coalesce(try_to_timestamp(CASE WHEN isnull(order_time#6624) THEN cast(null as string) WHEN (trim(order_time#6624, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#6624, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#6624, None) END, Some(yyyy-MM-dd HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(order_time#6624) THEN cast(null as string) WHEN (trim(order_time#6624, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#6624, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#6624, None) END, Some(dd/MM/yyyy HH:mm:ss), TimestampType, Some(Etc/UTC), false), try_to_timestamp(CASE WHEN isnull(order_time#6624) THEN cast(null as string) WHEN (trim(order_time#6624, None) = ) THEN cast(null as string) WHEN (upper(trim(order_time#6624, None)) = NULL) THEN cast(null as string) ELSE trim(order_time#6624, None) END, Some(yyyy/MM/dd HH:mm:ss), TimestampType, Some(Etc/UTC), false)) AS order_time_clean#6845]
#                                                 +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825]
#                                                    +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_nocommas#6822, order_amount_clean#6824, isnotnull(order_amount_clean#6824) AS order_amount_valid#6825]
#                                                       +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_nocommas#6822, CASE WHEN (order_amount_clean#6823 < 0) THEN cast(null as int) ELSE order_amount_clean#6823 END AS order_amount_clean#6824]
#                                                          +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_nocommas#6822, CASE WHEN RLIKE(order_amount_nocommas#6822, ^\d+$) THEN cast(order_amount_nocommas#6822 as int) ELSE cast(null as int) END AS order_amount_clean#6823]
#                                                             +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, regexp_replace(order_amount#6818, ,, , 1) AS order_amount_nocommas#6822]
#                                                                +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, CASE WHEN (isnull(rating#6631) OR (trim(rating#6631, None) = )) THEN cast(null as string) ELSE trim(rating#6631, None) END AS rating#6820]
#                                                                   +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, CASE WHEN (isnull(payment_mode#6630) OR (trim(payment_mode#6630, None) = )) THEN cast(null as string) ELSE trim(payment_mode#6630, None) END AS payment_mode#6819, rating#6631]
#                                                                      +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, CASE WHEN (isnull(order_amount#6629) OR (trim(order_amount#6629, None) = )) THEN cast(null as string) ELSE trim(order_amount#6629, None) END AS order_amount#6818, payment_mode#6630, rating#6631]
#                                                                         +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, CASE WHEN (isnull(delivery_partner_id#6628) OR (trim(delivery_partner_id#6628, None) = )) THEN cast(null as string) ELSE trim(delivery_partner_id#6628, None) END AS delivery_partner_id#6817, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                            +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, CASE WHEN (isnull(delivery_status#6627) OR (trim(delivery_status#6627, None) = )) THEN cast(null as string) ELSE trim(delivery_status#6627, None) END AS delivery_status#6816, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                               +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, CASE WHEN (isnull(delivery_city#6623) OR (trim(delivery_city#6623, None) = )) THEN cast(null as string) ELSE trim(delivery_city#6623, None) END AS delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                                  +- Project [order_id#6811, customer_id#6812, restaurant_id#6813, CASE WHEN (isnull(restaurant_city#6622) OR (trim(restaurant_city#6622, None) = )) THEN cast(null as string) ELSE trim(restaurant_city#6622, None) END AS restaurant_city#6814, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                                     +- Project [order_id#6811, customer_id#6812, CASE WHEN (isnull(restaurant_id#6621) OR (trim(restaurant_id#6621, None) = )) THEN cast(null as string) ELSE trim(restaurant_id#6621, None) END AS restaurant_id#6813, restaurant_city#6622, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                                        +- Project [order_id#6811, CASE WHEN (isnull(customer_id#6620) OR (trim(customer_id#6620, None) = )) THEN cast(null as string) ELSE trim(customer_id#6620, None) END AS customer_id#6812, restaurant_id#6621, restaurant_city#6622, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                                           +- Project [CASE WHEN (isnull(order_id#6619) OR (trim(order_id#6619, None) = )) THEN cast(null as string) ELSE trim(order_id#6619, None) END AS order_id#6811, customer_id#6620, restaurant_id#6621, restaurant_city#6622, delivery_city#6623, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6627, delivery_partner_id#6628, order_amount#6629, payment_mode#6630, rating#6631]
#                                                                                              +- Relation [order_id#6619,customer_id#6620,restaurant_id#6621,restaurant_city#6622,delivery_city#6623,order_time#6624,pickup_time#6625,delivery_time#6626,delivery_status#6627,delivery_partner_id#6628,order_amount#6629,payment_mode#6630,rating#6631] csv
#
# == Optimized Logical Plan ==
# Aggregate [delivery_city#6815], [delivery_city#6815, round(avg(delivery_time_gap_min#6971), 2) AS avg_delivery_time_gap_min#10839, count(1) AS orders_count#10840L]
# +- Project [delivery_city#6815, delivery_time_gap_min#6971]
#    +- Filter (isnotnull(delivery_time_gap_negative#6968) AND (isnotnull(delivery_time_gap_min#6971) AND NOT delivery_time_gap_negative#6968))
#       +- InMemoryRelation [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6970, delivery_time_gap_min#6971, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields], StorageLevel(disk, memory, deserialized, 1 replicas)
#             +- AdaptiveSparkPlan isFinalPlan=false
#                +- Exchange hashpartitioning(delivery_city#6815, 200), REPARTITION_BY_COL, [plan_id=5983]
#                   +- InMemoryTableScan [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6970, delivery_time_gap_min#6971, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#                         +- InMemoryRelation [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6970, delivery_time_gap_min#6971, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields], StorageLevel(disk, memory, deserialized, 1 replicas)
#                               +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / 60.0) END AS prep_time_min#6970, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / 60.0) END AS delivery_time_gap_min#6971, total_fulfillment_time_min#6966, CASE WHEN isnull(prep_time_min#6964) THEN false ELSE (prep_time_min#6964 < 0.0) END AS prep_time_negative#6967, ... 2 more fields]
#                                  +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, isnotnull(order_time_clean#6845) AS order_time_valid#6848, isnotnull(pickup_time_clean#6846) AS pickup_time_valid#6849, isnotnull(delivery_time_clean#6847) AS delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / 60.0) END AS prep_time_min#6964, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / 60.0) END AS delivery_time_gap_min#6965, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / 60.0) END AS total_fulfillment_time_min#6966]
#                                     +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, isnotnull(order_amount_clean#6824) AS order_amount_valid#6825, coalesce(gettimestamp(CASE WHEN isnull(order_time#6624) THEN null WHEN (trim(order_time#6624, None) = ) THEN null WHEN (upper(trim(order_time#6624, None)) = NULL) THEN null ELSE trim(order_time#6624, None) END, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(order_time#6624) THEN null WHEN (trim(order_time#6624, None) = ) THEN null WHEN (upper(trim(order_time#6624, None)) = NULL) THEN null ELSE trim(order_time#6624, None) END, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(order_time#6624) THEN null WHEN (trim(order_time#6624, None) = ) THEN null WHEN (upper(trim(order_time#6624, None)) = NULL) THEN null ELSE trim(order_time#6624, None) END, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS order_time_clean#6845, coalesce(gettimestamp(CASE WHEN isnull(pickup_time#6625) THEN null WHEN (trim(pickup_time#6625, None) = ) THEN null WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN null ELSE trim(pickup_time#6625, None) END, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(pickup_time#6625) THEN null WHEN (trim(pickup_time#6625, None) = ) THEN null WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN null ELSE trim(pickup_time#6625, None) END, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(pickup_time#6625) THEN null WHEN (trim(pickup_time#6625, None) = ) THEN null WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN null ELSE trim(pickup_time#6625, None) END, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS pickup_time_clean#6846, coalesce(gettimestamp(CASE WHEN isnull(delivery_time#6626) THEN null WHEN (trim(delivery_time#6626, None) = ) THEN null WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN null ELSE trim(delivery_time#6626, None) END, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(delivery_time#6626) THEN null WHEN (trim(delivery_time#6626, None) = ) THEN null WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN null ELSE trim(delivery_time#6626, None) END, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(delivery_time#6626) THEN null WHEN (trim(delivery_time#6626, None) = ) THEN null WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN null ELSE trim(delivery_time#6626, None) END, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS delivery_time_clean#6847]
#                                        +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, CASE WHEN (order_amount_clean#6823 < 0) THEN null ELSE order_amount_clean#6823 END AS order_amount_clean#6824]
#                                           +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, CASE WHEN RLIKE(order_amount_nocommas#6822, ^\d+$) THEN cast(order_amount_nocommas#6822 as int) END AS order_amount_clean#6823]
#                                              +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, regexp_replace(order_amount#6818, ,, , 1) AS order_amount_nocommas#6822]
#                                                 +- *(1) Project [CASE WHEN (isnull(order_id#6619) OR (trim(order_id#6619, None) = )) THEN null ELSE trim(order_id#6619, None) END AS order_id#6811, CASE WHEN (isnull(customer_id#6620) OR (trim(customer_id#6620, None) = )) THEN null ELSE trim(customer_id#6620, None) END AS customer_id#6812, CASE WHEN (isnull(restaurant_id#6621) OR (trim(restaurant_id#6621, None) = )) THEN null ELSE trim(restaurant_id#6621, None) END AS restaurant_id#6813, CASE WHEN (isnull(restaurant_city#6622) OR (trim(restaurant_city#6622, None) = )) THEN null ELSE trim(restaurant_city#6622, None) END AS restaurant_city#6814, CASE WHEN (isnull(delivery_city#6623) OR (trim(delivery_city#6623, None) = )) THEN null ELSE trim(delivery_city#6623, None) END AS delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, CASE WHEN (isnull(delivery_status#6627) OR (trim(delivery_status#6627, None) = )) THEN null ELSE trim(delivery_status#6627, None) END AS delivery_status#6816, CASE WHEN (isnull(delivery_partner_id#6628) OR (trim(delivery_partner_id#6628, None) = )) THEN null ELSE trim(delivery_partner_id#6628, None) END AS delivery_partner_id#6817, CASE WHEN (isnull(order_amount#6629) OR (trim(order_amount#6629, None) = )) THEN null ELSE trim(order_amount#6629, None) END AS order_amount#6818, CASE WHEN (isnull(payment_mode#6630) OR (trim(payment_mode#6630, None) = )) THEN null ELSE trim(payment_mode#6630, None) END AS payment_mode#6819, CASE WHEN (isnull(rating#6631) OR (trim(rating#6631, None) = )) THEN null ELSE trim(rating#6631, None) END AS rating#6820]
#                                                    +- FileScan csv [order_id#6619,customer_id#6620,restaurant_id#6621,restaurant_city#6622,delivery_city#6623,order_time#6624,pickup_time#6625,delivery_time#6626,delivery_status#6627,delivery_partner_id#6628,order_amount#6629,payment_mode#6630,rating#6631] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/delivery_data.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<order_id:string,customer_id:string,restaurant_id:string,restaurant_city:string,delivery_ci...
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[delivery_city#6815], functions=[avg(delivery_time_gap_min#6971), count(1)], output=[delivery_city#6815, avg_delivery_time_gap_min#10839, orders_count#10840L])
#    +- Exchange hashpartitioning(delivery_city#6815, 200), ENSURE_REQUIREMENTS, [plan_id=6064]
#       +- HashAggregate(keys=[delivery_city#6815], functions=[partial_avg(delivery_time_gap_min#6971), partial_count(1)], output=[delivery_city#6815, sum#12110, count#12111L, count#12112L])
#          +- Project [delivery_city#6815, delivery_time_gap_min#6971]
#             +- Filter ((isnotnull(delivery_time_gap_negative#6968) AND isnotnull(delivery_time_gap_min#6971)) AND NOT delivery_time_gap_negative#6968)
#                +- InMemoryTableScan [delivery_city#6815, delivery_time_gap_min#6971, delivery_time_gap_negative#6968], [isnotnull(delivery_time_gap_negative#6968), isnotnull(delivery_time_gap_min#6971), NOT delivery_time_gap_negative#6968]
#                      +- InMemoryRelation [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6970, delivery_time_gap_min#6971, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields], StorageLevel(disk, memory, deserialized, 1 replicas)
#                            +- AdaptiveSparkPlan isFinalPlan=false
#                               +- Exchange hashpartitioning(delivery_city#6815, 200), REPARTITION_BY_COL, [plan_id=5983]
#                                  +- InMemoryTableScan [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6970, delivery_time_gap_min#6971, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields]
#                                        +- InMemoryRelation [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, prep_time_min#6970, delivery_time_gap_min#6971, total_fulfillment_time_min#6966, prep_time_negative#6967, ... 2 more fields], StorageLevel(disk, memory, deserialized, 1 replicas)
#                                              +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, order_time_valid#6848, pickup_time_valid#6849, delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / 60.0) END AS prep_time_min#6970, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / 60.0) END AS delivery_time_gap_min#6971, total_fulfillment_time_min#6966, CASE WHEN isnull(prep_time_min#6964) THEN false ELSE (prep_time_min#6964 < 0.0) END AS prep_time_negative#6967, ... 2 more fields]
#                                                 +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, order_amount_valid#6825, order_time_clean#6845, pickup_time_clean#6846, delivery_time_clean#6847, isnotnull(order_time_clean#6845) AS order_time_valid#6848, isnotnull(pickup_time_clean#6846) AS pickup_time_valid#6849, isnotnull(delivery_time_clean#6847) AS delivery_time_valid#6850, CASE WHEN (isnotnull(pickup_time_clean#6846) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(pickup_time_clean#6846 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / 60.0) END AS prep_time_min#6964, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(pickup_time_clean#6846)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(pickup_time_clean#6846 as bigint)) as double) / 60.0) END AS delivery_time_gap_min#6965, CASE WHEN (isnotnull(delivery_time_clean#6847) AND isnotnull(order_time_clean#6845)) THEN (cast((cast(delivery_time_clean#6847 as bigint) - cast(order_time_clean#6845 as bigint)) as double) / 60.0) END AS total_fulfillment_time_min#6966]
#                                                    +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, order_amount_clean#6824, isnotnull(order_amount_clean#6824) AS order_amount_valid#6825, coalesce(gettimestamp(CASE WHEN isnull(order_time#6624) THEN null WHEN (trim(order_time#6624, None) = ) THEN null WHEN (upper(trim(order_time#6624, None)) = NULL) THEN null ELSE trim(order_time#6624, None) END, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(order_time#6624) THEN null WHEN (trim(order_time#6624, None) = ) THEN null WHEN (upper(trim(order_time#6624, None)) = NULL) THEN null ELSE trim(order_time#6624, None) END, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(order_time#6624) THEN null WHEN (trim(order_time#6624, None) = ) THEN null WHEN (upper(trim(order_time#6624, None)) = NULL) THEN null ELSE trim(order_time#6624, None) END, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS order_time_clean#6845, coalesce(gettimestamp(CASE WHEN isnull(pickup_time#6625) THEN null WHEN (trim(pickup_time#6625, None) = ) THEN null WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN null ELSE trim(pickup_time#6625, None) END, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(pickup_time#6625) THEN null WHEN (trim(pickup_time#6625, None) = ) THEN null WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN null ELSE trim(pickup_time#6625, None) END, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(pickup_time#6625) THEN null WHEN (trim(pickup_time#6625, None) = ) THEN null WHEN (upper(trim(pickup_time#6625, None)) = NULL) THEN null ELSE trim(pickup_time#6625, None) END, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS pickup_time_clean#6846, coalesce(gettimestamp(CASE WHEN isnull(delivery_time#6626) THEN null WHEN (trim(delivery_time#6626, None) = ) THEN null WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN null ELSE trim(delivery_time#6626, None) END, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(delivery_time#6626) THEN null WHEN (trim(delivery_time#6626, None) = ) THEN null WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN null ELSE trim(delivery_time#6626, None) END, dd/MM/yyyy HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(CASE WHEN isnull(delivery_time#6626) THEN null WHEN (trim(delivery_time#6626, None) = ) THEN null WHEN (upper(trim(delivery_time#6626, None)) = NULL) THEN null ELSE trim(delivery_time#6626, None) END, yyyy/MM/dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) AS delivery_time_clean#6847]
#                                                       +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, CASE WHEN (order_amount_clean#6823 < 0) THEN null ELSE order_amount_clean#6823 END AS order_amount_clean#6824]
#                                                          +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, CASE WHEN RLIKE(order_amount_nocommas#6822, ^\d+$) THEN cast(order_amount_nocommas#6822 as int) END AS order_amount_clean#6823]
#                                                             +- *(1) Project [order_id#6811, customer_id#6812, restaurant_id#6813, restaurant_city#6814, delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, delivery_status#6816, delivery_partner_id#6817, order_amount#6818, payment_mode#6819, rating#6820, regexp_replace(order_amount#6818, ,, , 1) AS order_amount_nocommas#6822]
#                                                                +- *(1) Project [CASE WHEN (isnull(order_id#6619) OR (trim(order_id#6619, None) = )) THEN null ELSE trim(order_id#6619, None) END AS order_id#6811, CASE WHEN (isnull(customer_id#6620) OR (trim(customer_id#6620, None) = )) THEN null ELSE trim(customer_id#6620, None) END AS customer_id#6812, CASE WHEN (isnull(restaurant_id#6621) OR (trim(restaurant_id#6621, None) = )) THEN null ELSE trim(restaurant_id#6621, None) END AS restaurant_id#6813, CASE WHEN (isnull(restaurant_city#6622) OR (trim(restaurant_city#6622, None) = )) THEN null ELSE trim(restaurant_city#6622, None) END AS restaurant_city#6814, CASE WHEN (isnull(delivery_city#6623) OR (trim(delivery_city#6623, None) = )) THEN null ELSE trim(delivery_city#6623, None) END AS delivery_city#6815, order_time#6624, pickup_time#6625, delivery_time#6626, CASE WHEN (isnull(delivery_status#6627) OR (trim(delivery_status#6627, None) = )) THEN null ELSE trim(delivery_status#6627, None) END AS delivery_status#6816, CASE WHEN (isnull(delivery_partner_id#6628) OR (trim(delivery_partner_id#6628, None) = )) THEN null ELSE trim(delivery_partner_id#6628, None) END AS delivery_partner_id#6817, CASE WHEN (isnull(order_amount#6629) OR (trim(order_amount#6629, None) = )) THEN null ELSE trim(order_amount#6629, None) END AS order_amount#6818, CASE WHEN (isnull(payment_mode#6630) OR (trim(payment_mode#6630, None) = )) THEN null ELSE trim(payment_mode#6630, None) END AS payment_mode#6819, CASE WHEN (isnull(rating#6631) OR (trim(rating#6631, None) = )) THEN null ELSE trim(rating#6631, None) END AS rating#6820]
#                                                                   +- FileScan csv [order_id#6619,customer_id#6620,restaurant_id#6621,restaurant_city#6622,delivery_city#6623,order_time#6624,pickup_time#6625,delivery_time#6626,delivery_status#6627,delivery_partner_id#6628,order_amount#6629,payment_mode#6630,rating#6631] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/delivery_data.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<order_id:string,customer_id:string,restaurant_id:string,restaurant_city:string,delivery_ci...

# %% [markdown]
# # PHASE 9 – RDD

# %% [markdown]
# # Convert delivered orders to RDD

# %%
delivered_paid_df = df.filter(
    (col("delivery_status") == "DELIVERED") &
    col("order_amount_clean").isNotNull()
)

delivered_rdd = delivered_paid_df.rdd

# %% [markdown]
# # Compute:
# *   Total revenue using reduce
# *   Order count per city using map-reduce

# %%
amounts_rdd = delivered_rdd.map(lambda row: int(row["order_amount_clean"]))

if amounts_rdd.isEmpty():
    total_revenue = 0
else:
    total_revenue = amounts_rdd.reduce(lambda a, b: a + b)

total_revenue
# Out:
# 50591938

# %%
city_counts_rdd = (
    delivered_rdd
    .map(lambda row: (row["delivery_city"], 1))
    .reduceByKey(lambda a, b: a + b)
)

city_counts = city_counts_rdd.collect()
print("Delivered order count per city:")
for city, cnt in sorted(city_counts, key=lambda x: (-x[1], x[0] or "")):
    print(f"{city}: {cnt}")
# Out:
# Delivered order count per city:
# Bangalore: 4959
# Delhi: 4926
# Pune: 4924
# Chennai: 4849
# Hyderabad: 4805
# Kolkata: 4764
# Mumbai: 4740

# %% [markdown]
# # Explain why DataFrames are better here

# %% [markdown]
# *   Catalyst optimizer (auto logical/physical plan optimizations)
# *   Fewer shuffles, faster execution
# *   Built‑in aggregations/joins/window funcs (vectorized, efficient)
# *   Less code, easier maintenance and debugging
# *   Schema-aware, better type safety than Python lambdas
# *   SQL compatibility
# *   Better memory management vs Python RDD overhead
